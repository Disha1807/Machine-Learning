# %% [markdown]
# ## Hyperparameter optimization

# %% [markdown]
# hyper-parameters, i.e. the parameters that control the training/fitting process of the model.

# %% [markdown]
# The model has many right answers. So, how would you find the best parameters?
# - A method would be to evaluate all the combinations and see which one improves the metric. Let’s see how this is done.

# %%
best_accuracy = 0
best_parameters = {"a": 0, "b": 0, "c": 0}

# %%
# loop over all values for a, b & c
for a in range(1, 11):
 for b in range(1, 11):
    for c in range(1, 11):
        # inititalize model with current parameters
        model = MODEL(a, b, c)
        # fit the model
        model.fit(training_data)
        # make predictions
        preds = model.predict(validation_data)
        # calculate accuracy
        accuracy = metrics.accuracy_score(targets, preds)
        # save params if current accuracy
        # is greater than best accuracy
        if accuracy > best_accuracy:
            best_accuracy = accuracy
            best_parameters["a"] = a
            best_parameters["b"] = b
            best_parameters["c"] = c

# %% [markdown]
# A search over the grid to find the best combination of parameters is known as `grid search.`

# %%
import numpy as np
import pandas as pd
from sklearn import ensemble
from sklearn import metrics
from sklearn import model_selection

# %%
# read the training data
df = pd.read_csv(r"C:\Users\lenovo\Desktop\Disha Github\Machine Learning Approaches\Machine-Learning\datasets\train.csv")

# %%
df.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
#    three_g  touch_screen  wifi  price_range
# 0        0             0     1            1
# 1        1             1     0            2
# 2        1             1     0            2
# 3        1             0     0            2
# 4        1             1     0            1
#
# [5 rows x 21 columns]

# %%
# here we have training features
X = df.drop("price_range", axis=1).values
 # and the targets
y = df.price_range.values

# %%
 # define the model here
 # i am using random forest with n_jobs=-1
 # n_jobs=-1 => use all cores
classifier = ensemble.RandomForestClassifier(n_jobs=-1)

# %%
# define a grid of parameters
 # this can be a dictionary or a list of
 # dictionaries
param_grid = {
 "n_estimators": [100, 200, 250, 300, 400, 500],
 "max_depth": [1, 2, 5, 7, 11, 15],
 "criterion": ["gini", "entropy"]
 }

# %%
# initialize grid search
 # estimator is the model that we have defined
 # param_grid is the grid of parameters
 # we use accuracy as our metric. you can define your own
 # higher value of verbose implies a lot of details are printed
 # cv=5 means that we are using 5 fold cv (not stratified)
model = model_selection.GridSearchCV(
estimator=classifier, 
param_grid=param_grid, 
scoring="accuracy",
verbose=10, 
n_jobs=1,
cv=5
)

# %%
# fit the model and extract best score
model.fit(X, y)
print(f"Best score: {model.best_score_}")
# Out:
# Fitting 5 folds for each of 72 candidates, totalling 360 fits
# [CV 1/5; 1/72] START criterion=gini, max_depth=1, n_estimators=100..............
# [CV 1/5; 1/72] END criterion=gini, max_depth=1, n_estimators=100;, score=0.583 total time=   6.6s
# [CV 2/5; 1/72] START criterion=gini, max_depth=1, n_estimators=100..............
# [CV 2/5; 1/72] END criterion=gini, max_depth=1, n_estimators=100;, score=0.532 total time=   0.1s
# [CV 3/5; 1/72] START criterion=gini, max_depth=1, n_estimators=100..............
# [CV 3/5; 1/72] END criterion=gini, max_depth=1, n_estimators=100;, score=0.662 total time=   0.2s
# [CV 4/5; 1/72] START criterion=gini, max_depth=1, n_estimators=100..............
# [CV 4/5; 1/72] END criterion=gini, max_depth=1, n_estimators=100;, score=0.613 total time=   0.2s
# [CV 5/5; 1/72] START criterion=gini, max_depth=1, n_estimators=100..............
# [CV 5/5; 1/72] END criterion=gini, max_depth=1, n_estimators=100;, score=0.547 total time=   0.1s
# [CV 1/5; 2/72] START criterion=gini, max_depth=1, n_estimators=200..............
# [CV 1/5; 2/72] END criterion=gini, max_depth=1, n_estimators=200;, score=0.613 total time=   0.3s
# [CV 2/5; 2/72] START criterion=gini, max_depth=1, n_estimators=200..............
# [CV 2/5; 2/72] END criterion=gini, max_depth=1, n_estimators=200;, score=0.578 total time=   0.2s
# [CV 3/5; 2/72] START criterion=gini, max_depth=1, n_estimators=200..............
# [CV 3/5; 2/72] END criterion=gini, max_depth=1, n_estimators=200;, score=0.627 total time=   0.2s
# [CV 4/5; 2/72] START criterion=gini, max_depth=1, n_estimators=200..............
# [CV 4/5; 2/72] END criterion=gini, max_depth=1, n_estimators=200;, score=0.645 total time=   0.2s
# [CV 5/5; 2/72] START criterion=gini, max_depth=1, n_estimators=200..............
# [CV 5/5; 2/72] END criterion=gini, max_depth=1, n_estimators=200;, score=0.570 total time=   0.3s
# [CV 1/5; 3/72] START criterion=gini, max_depth=1, n_estimators=250..............
# [CV 1/5; 3/72] END criterion=gini, max_depth=1, n_estimators=250;, score=0.603 total time=   0.2s
# [CV 2/5; 3/72] START criterion=gini, max_depth=1, n_estimators=250..............
# [CV 2/5; 3/72] END criterion=gini, max_depth=1, n_estimators=250;, score=0.562 total time=   0.2s
# [CV 3/5; 3/72] START criterion=gini, max_depth=1, n_estimators=250..............
# [CV 3/5; 3/72] END criterion=gini, max_depth=1, n_estimators=250;, score=0.627 total time=   0.3s
# [CV 4/5; 3/72] START criterion=gini, max_depth=1, n_estimators=250..............
# [CV 4/5; 3/72] END criterion=gini, max_depth=1, n_estimators=250;, score=0.555 total time=   0.2s
# [CV 5/5; 3/72] START criterion=gini, max_depth=1, n_estimators=250..............
# [CV 5/5; 3/72] END criterion=gini, max_depth=1, n_estimators=250;, score=0.565 total time=   0.2s
# [CV 1/5; 4/72] START criterion=gini, max_depth=1, n_estimators=300..............
# [CV 1/5; 4/72] END criterion=gini, max_depth=1, n_estimators=300;, score=0.550 total time=   0.3s
# [CV 2/5; 4/72] START criterion=gini, max_depth=1, n_estimators=300..............
# [CV 2/5; 4/72] END criterion=gini, max_depth=1, n_estimators=300;, score=0.598 total time=   0.3s
# [CV 3/5; 4/72] START criterion=gini, max_depth=1, n_estimators=300..............
# [CV 3/5; 4/72] END criterion=gini, max_depth=1, n_estimators=300;, score=0.625 total time=   0.4s
# [CV 4/5; 4/72] START criterion=gini, max_depth=1, n_estimators=300..............
# [CV 4/5; 4/72] END criterion=gini, max_depth=1, n_estimators=300;, score=0.593 total time=   0.3s
# [CV 5/5; 4/72] START criterion=gini, max_depth=1, n_estimators=300..............
# [CV 5/5; 4/72] END criterion=gini, max_depth=1, n_estimators=300;, score=0.580 total time=   0.3s
# [CV 1/5; 5/72] START criterion=gini, max_depth=1, n_estimators=400..............
# [CV 1/5; 5/72] END criterion=gini, max_depth=1, n_estimators=400;, score=0.613 total time=   0.4s
# [CV 2/5; 5/72] START criterion=gini, max_depth=1, n_estimators=400..............
# [CV 2/5; 5/72] END criterion=gini, max_depth=1, n_estimators=400;, score=0.578 total time=   0.4s
# [CV 3/5; 5/72] START criterion=gini, max_depth=1, n_estimators=400..............
# [CV 3/5; 5/72] END criterion=gini, max_depth=1, n_estimators=400;, score=0.620 total time=   0.4s
# [CV 4/5; 5/72] START criterion=gini, max_depth=1, n_estimators=400..............
# [CV 4/5; 5/72] END criterion=gini, max_depth=1, n_estimators=400;, score=0.600 total time=   0.3s
# [CV 5/5; 5/72] START criterion=gini, max_depth=1, n_estimators=400..............
# [CV 5/5; 5/72] END criterion=gini, max_depth=1, n_estimators=400;, score=0.573 total time=   0.4s
# [CV 1/5; 6/72] START criterion=gini, max_depth=1, n_estimators=500..............
# [CV 1/5; 6/72] END criterion=gini, max_depth=1, n_estimators=500;, score=0.585 total time=   0.5s
# [CV 2/5; 6/72] START criterion=gini, max_depth=1, n_estimators=500..............
# [CV 2/5; 6/72] END criterion=gini, max_depth=1, n_estimators=500;, score=0.620 total time=   0.5s
# [CV 3/5; 6/72] START criterion=gini, max_depth=1, n_estimators=500..............
# [CV 3/5; 6/72] END criterion=gini, max_depth=1, n_estimators=500;, score=0.640 total time=   0.6s
# [CV 4/5; 6/72] START criterion=gini, max_depth=1, n_estimators=500..............
# [CV 4/5; 6/72] END criterion=gini, max_depth=1, n_estimators=500;, score=0.555 total time=   0.4s
# [CV 5/5; 6/72] START criterion=gini, max_depth=1, n_estimators=500..............
# [CV 5/5; 6/72] END criterion=gini, max_depth=1, n_estimators=500;, score=0.585 total time=   0.4s
# [CV 1/5; 7/72] START criterion=gini, max_depth=2, n_estimators=100..............
# [CV 1/5; 7/72] END criterion=gini, max_depth=2, n_estimators=100;, score=0.738 total time=   0.1s
# [CV 2/5; 7/72] START criterion=gini, max_depth=2, n_estimators=100..............
# [CV 2/5; 7/72] END criterion=gini, max_depth=2, n_estimators=100;, score=0.713 total time=   0.1s
# [CV 3/5; 7/72] START criterion=gini, max_depth=2, n_estimators=100..............
# [CV 3/5; 7/72] END criterion=gini, max_depth=2, n_estimators=100;, score=0.785 total time=   0.1s
# [CV 4/5; 7/72] START criterion=gini, max_depth=2, n_estimators=100..............
# [CV 4/5; 7/72] END criterion=gini, max_depth=2, n_estimators=100;, score=0.782 total time=   0.1s
# [CV 5/5; 7/72] START criterion=gini, max_depth=2, n_estimators=100..............
# [CV 5/5; 7/72] END criterion=gini, max_depth=2, n_estimators=100;, score=0.775 total time=   0.1s
# [CV 1/5; 8/72] START criterion=gini, max_depth=2, n_estimators=200..............
# [CV 1/5; 8/72] END criterion=gini, max_depth=2, n_estimators=200;, score=0.777 total time=   0.2s
# [CV 2/5; 8/72] START criterion=gini, max_depth=2, n_estimators=200..............
# [CV 2/5; 8/72] END criterion=gini, max_depth=2, n_estimators=200;, score=0.713 total time=   0.2s
# [CV 3/5; 8/72] START criterion=gini, max_depth=2, n_estimators=200..............
# [CV 3/5; 8/72] END criterion=gini, max_depth=2, n_estimators=200;, score=0.757 total time=   0.3s
# [CV 4/5; 8/72] START criterion=gini, max_depth=2, n_estimators=200..............
# [CV 4/5; 8/72] END criterion=gini, max_depth=2, n_estimators=200;, score=0.800 total time=   0.2s
# [CV 5/5; 8/72] START criterion=gini, max_depth=2, n_estimators=200..............
# [CV 5/5; 8/72] END criterion=gini, max_depth=2, n_estimators=200;, score=0.765 total time=   0.2s
# [CV 1/5; 9/72] START criterion=gini, max_depth=2, n_estimators=250..............
# [CV 1/5; 9/72] END criterion=gini, max_depth=2, n_estimators=250;, score=0.730 total time=   0.3s
# [CV 2/5; 9/72] START criterion=gini, max_depth=2, n_estimators=250..............
# [CV 2/5; 9/72] END criterion=gini, max_depth=2, n_estimators=250;, score=0.748 total time=   0.3s
# [CV 3/5; 9/72] START criterion=gini, max_depth=2, n_estimators=250..............
# [CV 3/5; 9/72] END criterion=gini, max_depth=2, n_estimators=250;, score=0.760 total time=   0.2s
# [CV 4/5; 9/72] START criterion=gini, max_depth=2, n_estimators=250..............
# [CV 4/5; 9/72] END criterion=gini, max_depth=2, n_estimators=250;, score=0.777 total time=   0.2s
# [CV 5/5; 9/72] START criterion=gini, max_depth=2, n_estimators=250..............
# [CV 5/5; 9/72] END criterion=gini, max_depth=2, n_estimators=250;, score=0.710 total time=   0.2s
# [CV 1/5; 10/72] START criterion=gini, max_depth=2, n_estimators=300.............
# [CV 1/5; 10/72] END criterion=gini, max_depth=2, n_estimators=300;, score=0.765 total time=   0.3s
# [CV 2/5; 10/72] START criterion=gini, max_depth=2, n_estimators=300.............
# [CV 2/5; 10/72] END criterion=gini, max_depth=2, n_estimators=300;, score=0.757 total time=   0.4s
# [CV 3/5; 10/72] START criterion=gini, max_depth=2, n_estimators=300.............
# [CV 3/5; 10/72] END criterion=gini, max_depth=2, n_estimators=300;, score=0.782 total time=   0.3s
# [CV 4/5; 10/72] START criterion=gini, max_depth=2, n_estimators=300.............
# [CV 4/5; 10/72] END criterion=gini, max_depth=2, n_estimators=300;, score=0.772 total time=   0.4s
# [CV 5/5; 10/72] START criterion=gini, max_depth=2, n_estimators=300.............
# [CV 5/5; 10/72] END criterion=gini, max_depth=2, n_estimators=300;, score=0.720 total time=   0.3s
# [CV 1/5; 11/72] START criterion=gini, max_depth=2, n_estimators=400.............
# [CV 1/5; 11/72] END criterion=gini, max_depth=2, n_estimators=400;, score=0.733 total time=   0.4s
# [CV 2/5; 11/72] START criterion=gini, max_depth=2, n_estimators=400.............
# [CV 2/5; 11/72] END criterion=gini, max_depth=2, n_estimators=400;, score=0.745 total time=   0.3s
# [CV 3/5; 11/72] START criterion=gini, max_depth=2, n_estimators=400.............
# [CV 3/5; 11/72] END criterion=gini, max_depth=2, n_estimators=400;, score=0.790 total time=   0.4s
# [CV 4/5; 11/72] START criterion=gini, max_depth=2, n_estimators=400.............
# [CV 4/5; 11/72] END criterion=gini, max_depth=2, n_estimators=400;, score=0.767 total time=   0.4s
# [CV 5/5; 11/72] START criterion=gini, max_depth=2, n_estimators=400.............
# [CV 5/5; 11/72] END criterion=gini, max_depth=2, n_estimators=400;, score=0.767 total time=   0.4s
# [CV 1/5; 12/72] START criterion=gini, max_depth=2, n_estimators=500.............
# [CV 1/5; 12/72] END criterion=gini, max_depth=2, n_estimators=500;, score=0.770 total time=   0.5s
# [CV 2/5; 12/72] START criterion=gini, max_depth=2, n_estimators=500.............
# [CV 2/5; 12/72] END criterion=gini, max_depth=2, n_estimators=500;, score=0.715 total time=   0.4s
# [CV 3/5; 12/72] START criterion=gini, max_depth=2, n_estimators=500.............
# [CV 3/5; 12/72] END criterion=gini, max_depth=2, n_estimators=500;, score=0.760 total time=   0.5s
# [CV 4/5; 12/72] START criterion=gini, max_depth=2, n_estimators=500.............
# [CV 4/5; 12/72] END criterion=gini, max_depth=2, n_estimators=500;, score=0.782 total time=   0.4s
# [CV 5/5; 12/72] START criterion=gini, max_depth=2, n_estimators=500.............
# [CV 5/5; 12/72] END criterion=gini, max_depth=2, n_estimators=500;, score=0.787 total time=   0.4s
# [CV 1/5; 13/72] START criterion=gini, max_depth=5, n_estimators=100.............
# [CV 1/5; 13/72] END criterion=gini, max_depth=5, n_estimators=100;, score=0.828 total time=   0.1s
# [CV 2/5; 13/72] START criterion=gini, max_depth=5, n_estimators=100.............
# [CV 2/5; 13/72] END criterion=gini, max_depth=5, n_estimators=100;, score=0.840 total time=   0.1s
# [CV 3/5; 13/72] START criterion=gini, max_depth=5, n_estimators=100.............
# [CV 3/5; 13/72] END criterion=gini, max_depth=5, n_estimators=100;, score=0.848 total time=   0.1s
# [CV 4/5; 13/72] START criterion=gini, max_depth=5, n_estimators=100.............
# [CV 4/5; 13/72] END criterion=gini, max_depth=5, n_estimators=100;, score=0.820 total time=   0.1s
# [CV 5/5; 13/72] START criterion=gini, max_depth=5, n_estimators=100.............
# [CV 5/5; 13/72] END criterion=gini, max_depth=5, n_estimators=100;, score=0.823 total time=   0.1s
# [CV 1/5; 14/72] START criterion=gini, max_depth=5, n_estimators=200.............
# [CV 1/5; 14/72] END criterion=gini, max_depth=5, n_estimators=200;, score=0.843 total time=   0.3s
# [CV 2/5; 14/72] START criterion=gini, max_depth=5, n_estimators=200.............
# [CV 2/5; 14/72] END criterion=gini, max_depth=5, n_estimators=200;, score=0.830 total time=   0.3s
# [CV 3/5; 14/72] START criterion=gini, max_depth=5, n_estimators=200.............
# [CV 3/5; 14/72] END criterion=gini, max_depth=5, n_estimators=200;, score=0.875 total time=   0.2s
# [CV 4/5; 14/72] START criterion=gini, max_depth=5, n_estimators=200.............
# [CV 4/5; 14/72] END criterion=gini, max_depth=5, n_estimators=200;, score=0.840 total time=   0.2s
# [CV 5/5; 14/72] START criterion=gini, max_depth=5, n_estimators=200.............
# [CV 5/5; 14/72] END criterion=gini, max_depth=5, n_estimators=200;, score=0.810 total time=   0.2s
# [CV 1/5; 15/72] START criterion=gini, max_depth=5, n_estimators=250.............
# [CV 1/5; 15/72] END criterion=gini, max_depth=5, n_estimators=250;, score=0.838 total time=   0.2s
# [CV 2/5; 15/72] START criterion=gini, max_depth=5, n_estimators=250.............
# [CV 2/5; 15/72] END criterion=gini, max_depth=5, n_estimators=250;, score=0.858 total time=   0.3s
# [CV 3/5; 15/72] START criterion=gini, max_depth=5, n_estimators=250.............
# [CV 3/5; 15/72] END criterion=gini, max_depth=5, n_estimators=250;, score=0.860 total time=   0.2s
# [CV 4/5; 15/72] START criterion=gini, max_depth=5, n_estimators=250.............
# [CV 4/5; 15/72] END criterion=gini, max_depth=5, n_estimators=250;, score=0.845 total time=   0.3s
# [CV 5/5; 15/72] START criterion=gini, max_depth=5, n_estimators=250.............
# [CV 5/5; 15/72] END criterion=gini, max_depth=5, n_estimators=250;, score=0.815 total time=   0.2s
# [CV 1/5; 16/72] START criterion=gini, max_depth=5, n_estimators=300.............
# [CV 1/5; 16/72] END criterion=gini, max_depth=5, n_estimators=300;, score=0.835 total time=   0.3s
# [CV 2/5; 16/72] START criterion=gini, max_depth=5, n_estimators=300.............
# [CV 2/5; 16/72] END criterion=gini, max_depth=5, n_estimators=300;, score=0.828 total time=   0.4s
# [CV 3/5; 16/72] START criterion=gini, max_depth=5, n_estimators=300.............
# [CV 3/5; 16/72] END criterion=gini, max_depth=5, n_estimators=300;, score=0.860 total time=   0.3s
# [CV 4/5; 16/72] START criterion=gini, max_depth=5, n_estimators=300.............
# [CV 4/5; 16/72] END criterion=gini, max_depth=5, n_estimators=300;, score=0.830 total time=   0.3s
# [CV 5/5; 16/72] START criterion=gini, max_depth=5, n_estimators=300.............
# [CV 5/5; 16/72] END criterion=gini, max_depth=5, n_estimators=300;, score=0.823 total time=   0.4s
# [CV 1/5; 17/72] START criterion=gini, max_depth=5, n_estimators=400.............
# [CV 1/5; 17/72] END criterion=gini, max_depth=5, n_estimators=400;, score=0.835 total time=   0.4s
# [CV 2/5; 17/72] START criterion=gini, max_depth=5, n_estimators=400.............
# [CV 2/5; 17/72] END criterion=gini, max_depth=5, n_estimators=400;, score=0.853 total time=   0.5s
# [CV 3/5; 17/72] START criterion=gini, max_depth=5, n_estimators=400.............
# [CV 3/5; 17/72] END criterion=gini, max_depth=5, n_estimators=400;, score=0.870 total time=   0.5s
# [CV 4/5; 17/72] START criterion=gini, max_depth=5, n_estimators=400.............
# [CV 4/5; 17/72] END criterion=gini, max_depth=5, n_estimators=400;, score=0.838 total time=   0.5s
# [CV 5/5; 17/72] START criterion=gini, max_depth=5, n_estimators=400.............
# [CV 5/5; 17/72] END criterion=gini, max_depth=5, n_estimators=400;, score=0.820 total time=   0.5s
# [CV 1/5; 18/72] START criterion=gini, max_depth=5, n_estimators=500.............
# [CV 1/5; 18/72] END criterion=gini, max_depth=5, n_estimators=500;, score=0.823 total time=   0.6s
# [CV 2/5; 18/72] START criterion=gini, max_depth=5, n_estimators=500.............
# [CV 2/5; 18/72] END criterion=gini, max_depth=5, n_estimators=500;, score=0.833 total time=   0.7s
# [CV 3/5; 18/72] START criterion=gini, max_depth=5, n_estimators=500.............
# [CV 3/5; 18/72] END criterion=gini, max_depth=5, n_estimators=500;, score=0.868 total time=   0.6s
# [CV 4/5; 18/72] START criterion=gini, max_depth=5, n_estimators=500.............
# [CV 4/5; 18/72] END criterion=gini, max_depth=5, n_estimators=500;, score=0.825 total time=   0.8s
# [CV 5/5; 18/72] START criterion=gini, max_depth=5, n_estimators=500.............
# [CV 5/5; 18/72] END criterion=gini, max_depth=5, n_estimators=500;, score=0.833 total time=   0.5s
# [CV 1/5; 19/72] START criterion=gini, max_depth=7, n_estimators=100.............
# [CV 1/5; 19/72] END criterion=gini, max_depth=7, n_estimators=100;, score=0.870 total time=   0.1s
# [CV 2/5; 19/72] START criterion=gini, max_depth=7, n_estimators=100.............
# [CV 2/5; 19/72] END criterion=gini, max_depth=7, n_estimators=100;, score=0.868 total time=   0.1s
# [CV 3/5; 19/72] START criterion=gini, max_depth=7, n_estimators=100.............
# [CV 3/5; 19/72] END criterion=gini, max_depth=7, n_estimators=100;, score=0.873 total time=   0.1s
# [CV 4/5; 19/72] START criterion=gini, max_depth=7, n_estimators=100.............
# [CV 4/5; 19/72] END criterion=gini, max_depth=7, n_estimators=100;, score=0.858 total time=   0.1s
# [CV 5/5; 19/72] START criterion=gini, max_depth=7, n_estimators=100.............
# [CV 5/5; 19/72] END criterion=gini, max_depth=7, n_estimators=100;, score=0.833 total time=   0.1s
# [CV 1/5; 20/72] START criterion=gini, max_depth=7, n_estimators=200.............
# [CV 1/5; 20/72] END criterion=gini, max_depth=7, n_estimators=200;, score=0.858 total time=   0.3s
# [CV 2/5; 20/72] START criterion=gini, max_depth=7, n_estimators=200.............
# [CV 2/5; 20/72] END criterion=gini, max_depth=7, n_estimators=200;, score=0.870 total time=   0.3s
# [CV 3/5; 20/72] START criterion=gini, max_depth=7, n_estimators=200.............
# [CV 3/5; 20/72] END criterion=gini, max_depth=7, n_estimators=200;, score=0.885 total time=   0.3s
# [CV 4/5; 20/72] START criterion=gini, max_depth=7, n_estimators=200.............
# [CV 4/5; 20/72] END criterion=gini, max_depth=7, n_estimators=200;, score=0.858 total time=   0.3s
# [CV 5/5; 20/72] START criterion=gini, max_depth=7, n_estimators=200.............
# [CV 5/5; 20/72] END criterion=gini, max_depth=7, n_estimators=200;, score=0.843 total time=   0.3s
# [CV 1/5; 21/72] START criterion=gini, max_depth=7, n_estimators=250.............
# [CV 1/5; 21/72] END criterion=gini, max_depth=7, n_estimators=250;, score=0.858 total time=   0.3s
# [CV 2/5; 21/72] START criterion=gini, max_depth=7, n_estimators=250.............
# [CV 2/5; 21/72] END criterion=gini, max_depth=7, n_estimators=250;, score=0.863 total time=   0.3s
# [CV 3/5; 21/72] START criterion=gini, max_depth=7, n_estimators=250.............
# [CV 3/5; 21/72] END criterion=gini, max_depth=7, n_estimators=250;, score=0.885 total time=   0.3s
# [CV 4/5; 21/72] START criterion=gini, max_depth=7, n_estimators=250.............
# [CV 4/5; 21/72] END criterion=gini, max_depth=7, n_estimators=250;, score=0.860 total time=   0.3s
# [CV 5/5; 21/72] START criterion=gini, max_depth=7, n_estimators=250.............
# [CV 5/5; 21/72] END criterion=gini, max_depth=7, n_estimators=250;, score=0.840 total time=   0.4s
# [CV 1/5; 22/72] START criterion=gini, max_depth=7, n_estimators=300.............
# [CV 1/5; 22/72] END criterion=gini, max_depth=7, n_estimators=300;, score=0.875 total time=   0.5s
# [CV 2/5; 22/72] START criterion=gini, max_depth=7, n_estimators=300.............
# [CV 2/5; 22/72] END criterion=gini, max_depth=7, n_estimators=300;, score=0.860 total time=   0.4s
# [CV 3/5; 22/72] START criterion=gini, max_depth=7, n_estimators=300.............
# [CV 3/5; 22/72] END criterion=gini, max_depth=7, n_estimators=300;, score=0.875 total time=   0.5s
# [CV 4/5; 22/72] START criterion=gini, max_depth=7, n_estimators=300.............
# [CV 4/5; 22/72] END criterion=gini, max_depth=7, n_estimators=300;, score=0.868 total time=   0.4s
# [CV 5/5; 22/72] START criterion=gini, max_depth=7, n_estimators=300.............
# [CV 5/5; 22/72] END criterion=gini, max_depth=7, n_estimators=300;, score=0.843 total time=   0.4s
# [CV 1/5; 23/72] START criterion=gini, max_depth=7, n_estimators=400.............
# [CV 1/5; 23/72] END criterion=gini, max_depth=7, n_estimators=400;, score=0.865 total time=   0.5s
# [CV 2/5; 23/72] START criterion=gini, max_depth=7, n_estimators=400.............
# [CV 2/5; 23/72] END criterion=gini, max_depth=7, n_estimators=400;, score=0.863 total time=   0.5s
# [CV 3/5; 23/72] START criterion=gini, max_depth=7, n_estimators=400.............
# [CV 3/5; 23/72] END criterion=gini, max_depth=7, n_estimators=400;, score=0.880 total time=   0.5s
# [CV 4/5; 23/72] START criterion=gini, max_depth=7, n_estimators=400.............
# [CV 4/5; 23/72] END criterion=gini, max_depth=7, n_estimators=400;, score=0.868 total time=   0.6s
# [CV 5/5; 23/72] START criterion=gini, max_depth=7, n_estimators=400.............
# [CV 5/5; 23/72] END criterion=gini, max_depth=7, n_estimators=400;, score=0.843 total time=   0.6s
# [CV 1/5; 24/72] START criterion=gini, max_depth=7, n_estimators=500.............
# [CV 1/5; 24/72] END criterion=gini, max_depth=7, n_estimators=500;, score=0.880 total time=   0.6s
# [CV 2/5; 24/72] START criterion=gini, max_depth=7, n_estimators=500.............
# [CV 2/5; 24/72] END criterion=gini, max_depth=7, n_estimators=500;, score=0.870 total time=   0.7s
# [CV 3/5; 24/72] START criterion=gini, max_depth=7, n_estimators=500.............
# [CV 3/5; 24/72] END criterion=gini, max_depth=7, n_estimators=500;, score=0.895 total time=   0.7s
# [CV 4/5; 24/72] START criterion=gini, max_depth=7, n_estimators=500.............
# [CV 4/5; 24/72] END criterion=gini, max_depth=7, n_estimators=500;, score=0.858 total time=   0.6s
# [CV 5/5; 24/72] START criterion=gini, max_depth=7, n_estimators=500.............
# [CV 5/5; 24/72] END criterion=gini, max_depth=7, n_estimators=500;, score=0.838 total time=   0.6s
# [CV 1/5; 25/72] START criterion=gini, max_depth=11, n_estimators=100............
# [CV 1/5; 25/72] END criterion=gini, max_depth=11, n_estimators=100;, score=0.868 total time=   0.1s
# [CV 2/5; 25/72] START criterion=gini, max_depth=11, n_estimators=100............
# [CV 2/5; 25/72] END criterion=gini, max_depth=11, n_estimators=100;, score=0.875 total time=   0.1s
# [CV 3/5; 25/72] START criterion=gini, max_depth=11, n_estimators=100............
# [CV 3/5; 25/72] END criterion=gini, max_depth=11, n_estimators=100;, score=0.877 total time=   0.1s
# [CV 4/5; 25/72] START criterion=gini, max_depth=11, n_estimators=100............
# [CV 4/5; 25/72] END criterion=gini, max_depth=11, n_estimators=100;, score=0.868 total time=   0.1s
# [CV 5/5; 25/72] START criterion=gini, max_depth=11, n_estimators=100............
# [CV 5/5; 25/72] END criterion=gini, max_depth=11, n_estimators=100;, score=0.863 total time=   0.1s
# [CV 1/5; 26/72] START criterion=gini, max_depth=11, n_estimators=200............
# [CV 1/5; 26/72] END criterion=gini, max_depth=11, n_estimators=200;, score=0.875 total time=   0.3s
# [CV 2/5; 26/72] START criterion=gini, max_depth=11, n_estimators=200............
# [CV 2/5; 26/72] END criterion=gini, max_depth=11, n_estimators=200;, score=0.877 total time=   0.3s
# [CV 3/5; 26/72] START criterion=gini, max_depth=11, n_estimators=200............
# [CV 3/5; 26/72] END criterion=gini, max_depth=11, n_estimators=200;, score=0.895 total time=   0.3s
# [CV 4/5; 26/72] START criterion=gini, max_depth=11, n_estimators=200............
# [CV 4/5; 26/72] END criterion=gini, max_depth=11, n_estimators=200;, score=0.885 total time=   0.3s
# [CV 5/5; 26/72] START criterion=gini, max_depth=11, n_estimators=200............
# [CV 5/5; 26/72] END criterion=gini, max_depth=11, n_estimators=200;, score=0.858 total time=   0.3s
# [CV 1/5; 27/72] START criterion=gini, max_depth=11, n_estimators=250............
# [CV 1/5; 27/72] END criterion=gini, max_depth=11, n_estimators=250;, score=0.880 total time=   0.4s
# [CV 2/5; 27/72] START criterion=gini, max_depth=11, n_estimators=250............
# [CV 2/5; 27/72] END criterion=gini, max_depth=11, n_estimators=250;, score=0.890 total time=   0.4s
# [CV 3/5; 27/72] START criterion=gini, max_depth=11, n_estimators=250............
# [CV 3/5; 27/72] END criterion=gini, max_depth=11, n_estimators=250;, score=0.902 total time=   0.3s
# [CV 4/5; 27/72] START criterion=gini, max_depth=11, n_estimators=250............
# [CV 4/5; 27/72] END criterion=gini, max_depth=11, n_estimators=250;, score=0.880 total time=   0.3s
# [CV 5/5; 27/72] START criterion=gini, max_depth=11, n_estimators=250............
# [CV 5/5; 27/72] END criterion=gini, max_depth=11, n_estimators=250;, score=0.860 total time=   0.4s
# [CV 1/5; 28/72] START criterion=gini, max_depth=11, n_estimators=300............
# [CV 1/5; 28/72] END criterion=gini, max_depth=11, n_estimators=300;, score=0.875 total time=   0.5s
# [CV 2/5; 28/72] START criterion=gini, max_depth=11, n_estimators=300............
# [CV 2/5; 28/72] END criterion=gini, max_depth=11, n_estimators=300;, score=0.895 total time=   0.4s
# [CV 3/5; 28/72] START criterion=gini, max_depth=11, n_estimators=300............
# [CV 3/5; 28/72] END criterion=gini, max_depth=11, n_estimators=300;, score=0.892 total time=   0.5s
# [CV 4/5; 28/72] START criterion=gini, max_depth=11, n_estimators=300............
# [CV 4/5; 28/72] END criterion=gini, max_depth=11, n_estimators=300;, score=0.877 total time=   0.4s
# [CV 5/5; 28/72] START criterion=gini, max_depth=11, n_estimators=300............
# [CV 5/5; 28/72] END criterion=gini, max_depth=11, n_estimators=300;, score=0.860 total time=   0.4s
# [CV 1/5; 29/72] START criterion=gini, max_depth=11, n_estimators=400............
# [CV 1/5; 29/72] END criterion=gini, max_depth=11, n_estimators=400;, score=0.877 total time=   0.5s
# [CV 2/5; 29/72] START criterion=gini, max_depth=11, n_estimators=400............
# [CV 2/5; 29/72] END criterion=gini, max_depth=11, n_estimators=400;, score=0.887 total time=   0.5s
# [CV 3/5; 29/72] START criterion=gini, max_depth=11, n_estimators=400............
# [CV 3/5; 29/72] END criterion=gini, max_depth=11, n_estimators=400;, score=0.895 total time=   0.5s
# [CV 4/5; 29/72] START criterion=gini, max_depth=11, n_estimators=400............
# [CV 4/5; 29/72] END criterion=gini, max_depth=11, n_estimators=400;, score=0.880 total time=   0.5s
# [CV 5/5; 29/72] START criterion=gini, max_depth=11, n_estimators=400............
# [CV 5/5; 29/72] END criterion=gini, max_depth=11, n_estimators=400;, score=0.860 total time=   0.5s
# [CV 1/5; 30/72] START criterion=gini, max_depth=11, n_estimators=500............
# [CV 1/5; 30/72] END criterion=gini, max_depth=11, n_estimators=500;, score=0.882 total time=   0.5s
# [CV 2/5; 30/72] START criterion=gini, max_depth=11, n_estimators=500............
# [CV 2/5; 30/72] END criterion=gini, max_depth=11, n_estimators=500;, score=0.887 total time=   0.6s
# [CV 3/5; 30/72] START criterion=gini, max_depth=11, n_estimators=500............
# [CV 3/5; 30/72] END criterion=gini, max_depth=11, n_estimators=500;, score=0.900 total time=   0.6s
# [CV 4/5; 30/72] START criterion=gini, max_depth=11, n_estimators=500............
# [CV 4/5; 30/72] END criterion=gini, max_depth=11, n_estimators=500;, score=0.877 total time=   0.6s
# [CV 5/5; 30/72] START criterion=gini, max_depth=11, n_estimators=500............
# [CV 5/5; 30/72] END criterion=gini, max_depth=11, n_estimators=500;, score=0.870 total time=   0.5s
# [CV 1/5; 31/72] START criterion=gini, max_depth=15, n_estimators=100............
# [CV 1/5; 31/72] END criterion=gini, max_depth=15, n_estimators=100;, score=0.880 total time=   0.1s
# [CV 2/5; 31/72] START criterion=gini, max_depth=15, n_estimators=100............
# [CV 2/5; 31/72] END criterion=gini, max_depth=15, n_estimators=100;, score=0.887 total time=   0.1s
# [CV 3/5; 31/72] START criterion=gini, max_depth=15, n_estimators=100............
# [CV 3/5; 31/72] END criterion=gini, max_depth=15, n_estimators=100;, score=0.892 total time=   0.1s
# [CV 4/5; 31/72] START criterion=gini, max_depth=15, n_estimators=100............
# [CV 4/5; 31/72] END criterion=gini, max_depth=15, n_estimators=100;, score=0.880 total time=   0.1s
# [CV 5/5; 31/72] START criterion=gini, max_depth=15, n_estimators=100............
# [CV 5/5; 31/72] END criterion=gini, max_depth=15, n_estimators=100;, score=0.840 total time=   0.1s
# [CV 1/5; 32/72] START criterion=gini, max_depth=15, n_estimators=200............
# [CV 1/5; 32/72] END criterion=gini, max_depth=15, n_estimators=200;, score=0.865 total time=   0.3s
# [CV 2/5; 32/72] START criterion=gini, max_depth=15, n_estimators=200............
# [CV 2/5; 32/72] END criterion=gini, max_depth=15, n_estimators=200;, score=0.890 total time=   0.3s
# [CV 3/5; 32/72] START criterion=gini, max_depth=15, n_estimators=200............
# [CV 3/5; 32/72] END criterion=gini, max_depth=15, n_estimators=200;, score=0.910 total time=   0.3s
# [CV 4/5; 32/72] START criterion=gini, max_depth=15, n_estimators=200............
# [CV 4/5; 32/72] END criterion=gini, max_depth=15, n_estimators=200;, score=0.855 total time=   0.3s
# [CV 5/5; 32/72] START criterion=gini, max_depth=15, n_estimators=200............
# [CV 5/5; 32/72] END criterion=gini, max_depth=15, n_estimators=200;, score=0.870 total time=   0.2s
# [CV 1/5; 33/72] START criterion=gini, max_depth=15, n_estimators=250............
# [CV 1/5; 33/72] END criterion=gini, max_depth=15, n_estimators=250;, score=0.875 total time=   0.3s
# [CV 2/5; 33/72] START criterion=gini, max_depth=15, n_estimators=250............
# [CV 2/5; 33/72] END criterion=gini, max_depth=15, n_estimators=250;, score=0.880 total time=   0.3s
# [CV 3/5; 33/72] START criterion=gini, max_depth=15, n_estimators=250............
# [CV 3/5; 33/72] END criterion=gini, max_depth=15, n_estimators=250;, score=0.897 total time=   0.3s
# [CV 4/5; 33/72] START criterion=gini, max_depth=15, n_estimators=250............
# [CV 4/5; 33/72] END criterion=gini, max_depth=15, n_estimators=250;, score=0.877 total time=   0.3s
# [CV 5/5; 33/72] START criterion=gini, max_depth=15, n_estimators=250............
# [CV 5/5; 33/72] END criterion=gini, max_depth=15, n_estimators=250;, score=0.860 total time=   0.3s
# [CV 1/5; 34/72] START criterion=gini, max_depth=15, n_estimators=300............
# [CV 1/5; 34/72] END criterion=gini, max_depth=15, n_estimators=300;, score=0.882 total time=   0.6s
# [CV 2/5; 34/72] START criterion=gini, max_depth=15, n_estimators=300............
# [CV 2/5; 34/72] END criterion=gini, max_depth=15, n_estimators=300;, score=0.890 total time=   0.4s
# [CV 3/5; 34/72] START criterion=gini, max_depth=15, n_estimators=300............
# [CV 3/5; 34/72] END criterion=gini, max_depth=15, n_estimators=300;, score=0.905 total time=   0.6s
# [CV 4/5; 34/72] START criterion=gini, max_depth=15, n_estimators=300............
# [CV 4/5; 34/72] END criterion=gini, max_depth=15, n_estimators=300;, score=0.880 total time=   0.4s
# [CV 5/5; 34/72] START criterion=gini, max_depth=15, n_estimators=300............
# [CV 5/5; 34/72] END criterion=gini, max_depth=15, n_estimators=300;, score=0.863 total time=   0.4s
# [CV 1/5; 35/72] START criterion=gini, max_depth=15, n_estimators=400............
# [CV 1/5; 35/72] END criterion=gini, max_depth=15, n_estimators=400;, score=0.882 total time=   0.5s
# [CV 2/5; 35/72] START criterion=gini, max_depth=15, n_estimators=400............
# [CV 2/5; 35/72] END criterion=gini, max_depth=15, n_estimators=400;, score=0.892 total time=   0.5s
# [CV 3/5; 35/72] START criterion=gini, max_depth=15, n_estimators=400............
# [CV 3/5; 35/72] END criterion=gini, max_depth=15, n_estimators=400;, score=0.895 total time=   0.5s
# [CV 4/5; 35/72] START criterion=gini, max_depth=15, n_estimators=400............
# [CV 4/5; 35/72] END criterion=gini, max_depth=15, n_estimators=400;, score=0.882 total time=   0.5s
# [CV 5/5; 35/72] START criterion=gini, max_depth=15, n_estimators=400............
# [CV 5/5; 35/72] END criterion=gini, max_depth=15, n_estimators=400;, score=0.863 total time=   0.5s
# [CV 1/5; 36/72] START criterion=gini, max_depth=15, n_estimators=500............
# [CV 1/5; 36/72] END criterion=gini, max_depth=15, n_estimators=500;, score=0.880 total time=   0.5s
# [CV 2/5; 36/72] START criterion=gini, max_depth=15, n_estimators=500............
# [CV 2/5; 36/72] END criterion=gini, max_depth=15, n_estimators=500;, score=0.890 total time=   0.6s
# [CV 3/5; 36/72] START criterion=gini, max_depth=15, n_estimators=500............
# [CV 3/5; 36/72] END criterion=gini, max_depth=15, n_estimators=500;, score=0.900 total time=   0.5s
# [CV 4/5; 36/72] START criterion=gini, max_depth=15, n_estimators=500............
# [CV 4/5; 36/72] END criterion=gini, max_depth=15, n_estimators=500;, score=0.882 total time=   0.7s
# [CV 5/5; 36/72] START criterion=gini, max_depth=15, n_estimators=500............
# [CV 5/5; 36/72] END criterion=gini, max_depth=15, n_estimators=500;, score=0.870 total time=   0.6s
# [CV 1/5; 37/72] START criterion=entropy, max_depth=1, n_estimators=100..........
# [CV 1/5; 37/72] END criterion=entropy, max_depth=1, n_estimators=100;, score=0.603 total time=   0.1s
# [CV 2/5; 37/72] START criterion=entropy, max_depth=1, n_estimators=100..........
# [CV 2/5; 37/72] END criterion=entropy, max_depth=1, n_estimators=100;, score=0.545 total time=   0.1s
# [CV 3/5; 37/72] START criterion=entropy, max_depth=1, n_estimators=100..........
# [CV 3/5; 37/72] END criterion=entropy, max_depth=1, n_estimators=100;, score=0.583 total time=   0.1s
# [CV 4/5; 37/72] START criterion=entropy, max_depth=1, n_estimators=100..........
# [CV 4/5; 37/72] END criterion=entropy, max_depth=1, n_estimators=100;, score=0.557 total time=   0.1s
# [CV 5/5; 37/72] START criterion=entropy, max_depth=1, n_estimators=100..........
# [CV 5/5; 37/72] END criterion=entropy, max_depth=1, n_estimators=100;, score=0.550 total time=   0.1s
# [CV 1/5; 38/72] START criterion=entropy, max_depth=1, n_estimators=200..........
# [CV 1/5; 38/72] END criterion=entropy, max_depth=1, n_estimators=200;, score=0.578 total time=   0.2s
# [CV 2/5; 38/72] START criterion=entropy, max_depth=1, n_estimators=200..........
# [CV 2/5; 38/72] END criterion=entropy, max_depth=1, n_estimators=200;, score=0.547 total time=   0.2s
# [CV 3/5; 38/72] START criterion=entropy, max_depth=1, n_estimators=200..........
# [CV 3/5; 38/72] END criterion=entropy, max_depth=1, n_estimators=200;, score=0.585 total time=   0.2s
# [CV 4/5; 38/72] START criterion=entropy, max_depth=1, n_estimators=200..........
# [CV 4/5; 38/72] END criterion=entropy, max_depth=1, n_estimators=200;, score=0.535 total time=   0.2s
# [CV 5/5; 38/72] START criterion=entropy, max_depth=1, n_estimators=200..........
# [CV 5/5; 38/72] END criterion=entropy, max_depth=1, n_estimators=200;, score=0.555 total time=   0.2s
# [CV 1/5; 39/72] START criterion=entropy, max_depth=1, n_estimators=250..........
# [CV 1/5; 39/72] END criterion=entropy, max_depth=1, n_estimators=250;, score=0.598 total time=   0.2s
# [CV 2/5; 39/72] START criterion=entropy, max_depth=1, n_estimators=250..........
# [CV 2/5; 39/72] END criterion=entropy, max_depth=1, n_estimators=250;, score=0.532 total time=   0.3s
# [CV 3/5; 39/72] START criterion=entropy, max_depth=1, n_estimators=250..........
# [CV 3/5; 39/72] END criterion=entropy, max_depth=1, n_estimators=250;, score=0.540 total time=   0.2s
# [CV 4/5; 39/72] START criterion=entropy, max_depth=1, n_estimators=250..........
# [CV 4/5; 39/72] END criterion=entropy, max_depth=1, n_estimators=250;, score=0.578 total time=   0.2s
# [CV 5/5; 39/72] START criterion=entropy, max_depth=1, n_estimators=250..........
# [CV 5/5; 39/72] END criterion=entropy, max_depth=1, n_estimators=250;, score=0.550 total time=   0.2s
# [CV 1/5; 40/72] START criterion=entropy, max_depth=1, n_estimators=300..........
# [CV 1/5; 40/72] END criterion=entropy, max_depth=1, n_estimators=300;, score=0.568 total time=   0.3s
# [CV 2/5; 40/72] START criterion=entropy, max_depth=1, n_estimators=300..........
# [CV 2/5; 40/72] END criterion=entropy, max_depth=1, n_estimators=300;, score=0.545 total time=   0.3s
# [CV 3/5; 40/72] START criterion=entropy, max_depth=1, n_estimators=300..........
# [CV 3/5; 40/72] END criterion=entropy, max_depth=1, n_estimators=300;, score=0.547 total time=   0.3s
# [CV 4/5; 40/72] START criterion=entropy, max_depth=1, n_estimators=300..........
# [CV 4/5; 40/72] END criterion=entropy, max_depth=1, n_estimators=300;, score=0.550 total time=   0.4s
# [CV 5/5; 40/72] START criterion=entropy, max_depth=1, n_estimators=300..........
# [CV 5/5; 40/72] END criterion=entropy, max_depth=1, n_estimators=300;, score=0.552 total time=   0.3s
# [CV 1/5; 41/72] START criterion=entropy, max_depth=1, n_estimators=400..........
# [CV 1/5; 41/72] END criterion=entropy, max_depth=1, n_estimators=400;, score=0.590 total time=   0.4s
# [CV 2/5; 41/72] START criterion=entropy, max_depth=1, n_estimators=400..........
# [CV 2/5; 41/72] END criterion=entropy, max_depth=1, n_estimators=400;, score=0.557 total time=   0.4s
# [CV 3/5; 41/72] START criterion=entropy, max_depth=1, n_estimators=400..........
# [CV 3/5; 41/72] END criterion=entropy, max_depth=1, n_estimators=400;, score=0.573 total time=   0.3s
# [CV 4/5; 41/72] START criterion=entropy, max_depth=1, n_estimators=400..........
# [CV 4/5; 41/72] END criterion=entropy, max_depth=1, n_estimators=400;, score=0.537 total time=   0.4s
# [CV 5/5; 41/72] START criterion=entropy, max_depth=1, n_estimators=400..........
# [CV 5/5; 41/72] END criterion=entropy, max_depth=1, n_estimators=400;, score=0.550 total time=   0.4s
# [CV 1/5; 42/72] START criterion=entropy, max_depth=1, n_estimators=500..........
# [CV 1/5; 42/72] END criterion=entropy, max_depth=1, n_estimators=500;, score=0.542 total time=   0.4s
# [CV 2/5; 42/72] START criterion=entropy, max_depth=1, n_estimators=500..........
# [CV 2/5; 42/72] END criterion=entropy, max_depth=1, n_estimators=500;, score=0.568 total time=   0.4s
# [CV 3/5; 42/72] START criterion=entropy, max_depth=1, n_estimators=500..........
# [CV 3/5; 42/72] END criterion=entropy, max_depth=1, n_estimators=500;, score=0.542 total time=   0.5s
# [CV 4/5; 42/72] START criterion=entropy, max_depth=1, n_estimators=500..........
# [CV 4/5; 42/72] END criterion=entropy, max_depth=1, n_estimators=500;, score=0.560 total time=   0.5s
# [CV 5/5; 42/72] START criterion=entropy, max_depth=1, n_estimators=500..........
# [CV 5/5; 42/72] END criterion=entropy, max_depth=1, n_estimators=500;, score=0.562 total time=   0.4s
# [CV 1/5; 43/72] START criterion=entropy, max_depth=2, n_estimators=100..........
# [CV 1/5; 43/72] END criterion=entropy, max_depth=2, n_estimators=100;, score=0.695 total time=   0.1s
# [CV 2/5; 43/72] START criterion=entropy, max_depth=2, n_estimators=100..........
# [CV 2/5; 43/72] END criterion=entropy, max_depth=2, n_estimators=100;, score=0.710 total time=   0.1s
# [CV 3/5; 43/72] START criterion=entropy, max_depth=2, n_estimators=100..........
# [CV 3/5; 43/72] END criterion=entropy, max_depth=2, n_estimators=100;, score=0.762 total time=   0.1s
# [CV 4/5; 43/72] START criterion=entropy, max_depth=2, n_estimators=100..........
# [CV 4/5; 43/72] END criterion=entropy, max_depth=2, n_estimators=100;, score=0.642 total time=   0.1s
# [CV 5/5; 43/72] START criterion=entropy, max_depth=2, n_estimators=100..........
# [CV 5/5; 43/72] END criterion=entropy, max_depth=2, n_estimators=100;, score=0.568 total time=   0.1s
# [CV 1/5; 44/72] START criterion=entropy, max_depth=2, n_estimators=200..........
# [CV 1/5; 44/72] END criterion=entropy, max_depth=2, n_estimators=200;, score=0.700 total time=   0.2s
# [CV 2/5; 44/72] START criterion=entropy, max_depth=2, n_estimators=200..........
# [CV 2/5; 44/72] END criterion=entropy, max_depth=2, n_estimators=200;, score=0.705 total time=   0.2s
# [CV 3/5; 44/72] START criterion=entropy, max_depth=2, n_estimators=200..........
# [CV 3/5; 44/72] END criterion=entropy, max_depth=2, n_estimators=200;, score=0.685 total time=   0.2s
# [CV 4/5; 44/72] START criterion=entropy, max_depth=2, n_estimators=200..........
# [CV 4/5; 44/72] END criterion=entropy, max_depth=2, n_estimators=200;, score=0.675 total time=   0.2s
# [CV 5/5; 44/72] START criterion=entropy, max_depth=2, n_estimators=200..........
# [CV 5/5; 44/72] END criterion=entropy, max_depth=2, n_estimators=200;, score=0.708 total time=   0.3s
# [CV 1/5; 45/72] START criterion=entropy, max_depth=2, n_estimators=250..........
# [CV 1/5; 45/72] END criterion=entropy, max_depth=2, n_estimators=250;, score=0.698 total time=   0.3s
# [CV 2/5; 45/72] START criterion=entropy, max_depth=2, n_estimators=250..........
# [CV 2/5; 45/72] END criterion=entropy, max_depth=2, n_estimators=250;, score=0.685 total time=   0.2s
# [CV 3/5; 45/72] START criterion=entropy, max_depth=2, n_estimators=250..........
# [CV 3/5; 45/72] END criterion=entropy, max_depth=2, n_estimators=250;, score=0.690 total time=   0.2s
# [CV 4/5; 45/72] START criterion=entropy, max_depth=2, n_estimators=250..........
# [CV 4/5; 45/72] END criterion=entropy, max_depth=2, n_estimators=250;, score=0.708 total time=   0.2s
# [CV 5/5; 45/72] START criterion=entropy, max_depth=2, n_estimators=250..........
# [CV 5/5; 45/72] END criterion=entropy, max_depth=2, n_estimators=250;, score=0.695 total time=   0.2s
# [CV 1/5; 46/72] START criterion=entropy, max_depth=2, n_estimators=300..........
# [CV 1/5; 46/72] END criterion=entropy, max_depth=2, n_estimators=300;, score=0.667 total time=   0.4s
# [CV 2/5; 46/72] START criterion=entropy, max_depth=2, n_estimators=300..........
# [CV 2/5; 46/72] END criterion=entropy, max_depth=2, n_estimators=300;, score=0.660 total time=   0.4s
# [CV 3/5; 46/72] START criterion=entropy, max_depth=2, n_estimators=300..........
# [CV 3/5; 46/72] END criterion=entropy, max_depth=2, n_estimators=300;, score=0.672 total time=   0.3s
# [CV 4/5; 46/72] START criterion=entropy, max_depth=2, n_estimators=300..........
# [CV 4/5; 46/72] END criterion=entropy, max_depth=2, n_estimators=300;, score=0.728 total time=   0.3s
# [CV 5/5; 46/72] START criterion=entropy, max_depth=2, n_estimators=300..........
# [CV 5/5; 46/72] END criterion=entropy, max_depth=2, n_estimators=300;, score=0.700 total time=   0.3s
# [CV 1/5; 47/72] START criterion=entropy, max_depth=2, n_estimators=400..........
# [CV 1/5; 47/72] END criterion=entropy, max_depth=2, n_estimators=400;, score=0.685 total time=   0.4s
# [CV 2/5; 47/72] START criterion=entropy, max_depth=2, n_estimators=400..........
# [CV 2/5; 47/72] END criterion=entropy, max_depth=2, n_estimators=400;, score=0.647 total time=   0.4s
# [CV 3/5; 47/72] START criterion=entropy, max_depth=2, n_estimators=400..........
# [CV 3/5; 47/72] END criterion=entropy, max_depth=2, n_estimators=400;, score=0.690 total time=   0.4s
# [CV 4/5; 47/72] START criterion=entropy, max_depth=2, n_estimators=400..........
# [CV 4/5; 47/72] END criterion=entropy, max_depth=2, n_estimators=400;, score=0.695 total time=   0.4s
# [CV 5/5; 47/72] START criterion=entropy, max_depth=2, n_estimators=400..........
# [CV 5/5; 47/72] END criterion=entropy, max_depth=2, n_estimators=400;, score=0.660 total time=   0.4s
# [CV 1/5; 48/72] START criterion=entropy, max_depth=2, n_estimators=500..........
# [CV 1/5; 48/72] END criterion=entropy, max_depth=2, n_estimators=500;, score=0.705 total time=   0.5s
# [CV 2/5; 48/72] START criterion=entropy, max_depth=2, n_estimators=500..........
# [CV 2/5; 48/72] END criterion=entropy, max_depth=2, n_estimators=500;, score=0.703 total time=   0.6s
# [CV 3/5; 48/72] START criterion=entropy, max_depth=2, n_estimators=500..........
# [CV 3/5; 48/72] END criterion=entropy, max_depth=2, n_estimators=500;, score=0.655 total time=   0.5s
# [CV 4/5; 48/72] START criterion=entropy, max_depth=2, n_estimators=500..........
# [CV 4/5; 48/72] END criterion=entropy, max_depth=2, n_estimators=500;, score=0.695 total time=   0.4s
# [CV 5/5; 48/72] START criterion=entropy, max_depth=2, n_estimators=500..........
# [CV 5/5; 48/72] END criterion=entropy, max_depth=2, n_estimators=500;, score=0.677 total time=   0.5s
# [CV 1/5; 49/72] START criterion=entropy, max_depth=5, n_estimators=100..........
# [CV 1/5; 49/72] END criterion=entropy, max_depth=5, n_estimators=100;, score=0.823 total time=   0.1s
# [CV 2/5; 49/72] START criterion=entropy, max_depth=5, n_estimators=100..........
# [CV 2/5; 49/72] END criterion=entropy, max_depth=5, n_estimators=100;, score=0.820 total time=   0.1s
# [CV 3/5; 49/72] START criterion=entropy, max_depth=5, n_estimators=100..........
# [CV 3/5; 49/72] END criterion=entropy, max_depth=5, n_estimators=100;, score=0.840 total time=   0.1s
# [CV 4/5; 49/72] START criterion=entropy, max_depth=5, n_estimators=100..........
# [CV 4/5; 49/72] END criterion=entropy, max_depth=5, n_estimators=100;, score=0.838 total time=   0.1s
# [CV 5/5; 49/72] START criterion=entropy, max_depth=5, n_estimators=100..........
# [CV 5/5; 49/72] END criterion=entropy, max_depth=5, n_estimators=100;, score=0.835 total time=   0.1s
# [CV 1/5; 50/72] START criterion=entropy, max_depth=5, n_estimators=200..........
# [CV 1/5; 50/72] END criterion=entropy, max_depth=5, n_estimators=200;, score=0.830 total time=   0.2s
# [CV 2/5; 50/72] START criterion=entropy, max_depth=5, n_estimators=200..........
# [CV 2/5; 50/72] END criterion=entropy, max_depth=5, n_estimators=200;, score=0.855 total time=   0.2s
# [CV 3/5; 50/72] START criterion=entropy, max_depth=5, n_estimators=200..........
# [CV 3/5; 50/72] END criterion=entropy, max_depth=5, n_estimators=200;, score=0.863 total time=   0.2s
# [CV 4/5; 50/72] START criterion=entropy, max_depth=5, n_estimators=200..........
# [CV 4/5; 50/72] END criterion=entropy, max_depth=5, n_estimators=200;, score=0.830 total time=   0.2s
# [CV 5/5; 50/72] START criterion=entropy, max_depth=5, n_estimators=200..........
# [CV 5/5; 50/72] END criterion=entropy, max_depth=5, n_estimators=200;, score=0.828 total time=   0.2s
# [CV 1/5; 51/72] START criterion=entropy, max_depth=5, n_estimators=250..........
# [CV 1/5; 51/72] END criterion=entropy, max_depth=5, n_estimators=250;, score=0.835 total time=   0.2s
# [CV 2/5; 51/72] START criterion=entropy, max_depth=5, n_estimators=250..........
# [CV 2/5; 51/72] END criterion=entropy, max_depth=5, n_estimators=250;, score=0.833 total time=   0.2s
# [CV 3/5; 51/72] START criterion=entropy, max_depth=5, n_estimators=250..........
# [CV 3/5; 51/72] END criterion=entropy, max_depth=5, n_estimators=250;, score=0.855 total time=   0.3s
# [CV 4/5; 51/72] START criterion=entropy, max_depth=5, n_estimators=250..........
# [CV 4/5; 51/72] END criterion=entropy, max_depth=5, n_estimators=250;, score=0.835 total time=   0.2s
# [CV 5/5; 51/72] START criterion=entropy, max_depth=5, n_estimators=250..........
# [CV 5/5; 51/72] END criterion=entropy, max_depth=5, n_estimators=250;, score=0.828 total time=   0.2s
# [CV 1/5; 52/72] START criterion=entropy, max_depth=5, n_estimators=300..........
# [CV 1/5; 52/72] END criterion=entropy, max_depth=5, n_estimators=300;, score=0.835 total time=   0.4s
# [CV 2/5; 52/72] START criterion=entropy, max_depth=5, n_estimators=300..........
# [CV 2/5; 52/72] END criterion=entropy, max_depth=5, n_estimators=300;, score=0.855 total time=   0.4s
# [CV 3/5; 52/72] START criterion=entropy, max_depth=5, n_estimators=300..........
# [CV 3/5; 52/72] END criterion=entropy, max_depth=5, n_estimators=300;, score=0.850 total time=   0.4s
# [CV 4/5; 52/72] START criterion=entropy, max_depth=5, n_estimators=300..........
# [CV 4/5; 52/72] END criterion=entropy, max_depth=5, n_estimators=300;, score=0.838 total time=   0.3s
# [CV 5/5; 52/72] START criterion=entropy, max_depth=5, n_estimators=300..........
# [CV 5/5; 52/72] END criterion=entropy, max_depth=5, n_estimators=300;, score=0.833 total time=   0.4s
# [CV 1/5; 53/72] START criterion=entropy, max_depth=5, n_estimators=400..........
# [CV 1/5; 53/72] END criterion=entropy, max_depth=5, n_estimators=400;, score=0.840 total time=   0.5s
# [CV 2/5; 53/72] START criterion=entropy, max_depth=5, n_estimators=400..........
# [CV 2/5; 53/72] END criterion=entropy, max_depth=5, n_estimators=400;, score=0.840 total time=   0.6s
# [CV 3/5; 53/72] START criterion=entropy, max_depth=5, n_estimators=400..........
# [CV 3/5; 53/72] END criterion=entropy, max_depth=5, n_estimators=400;, score=0.858 total time=   0.5s
# [CV 4/5; 53/72] START criterion=entropy, max_depth=5, n_estimators=400..........
# [CV 4/5; 53/72] END criterion=entropy, max_depth=5, n_estimators=400;, score=0.838 total time=   0.4s
# [CV 5/5; 53/72] START criterion=entropy, max_depth=5, n_estimators=400..........
# ...
# [CV 4/5; 55/72] START criterion=entropy, max_depth=7, n_estimators=100..........
# [CV 4/5; 55/72] END criterion=entropy, max_depth=7, n_estimators=100;, score=0.843 total time=   0.1s
# [CV 5/5; 55/72] START criterion=entropy, max_depth=7, n_estimators=100..........
# [CV 5/5; 55/72] END criterion=entropy, max_depth=7, n_estimators=100;, score=0.843 total time=   0.1s
# [CV 1/5; 56/72] START criterion=entropy, max_depth=7, n_estimators=200..........
# [CV 1/5; 56/72] END criterion=entropy, max_depth=7, n_estimators=200;, score=0.870 total time=   0.3s
# [CV 2/5; 56/72] START criterion=entropy, max_depth=7, n_estimators=200..........
# [CV 2/5; 56/72] END criterion=entropy, max_depth=7, n_estimators=200;, score=0.853 total time=   0.3s
# [CV 3/5; 56/72] START criterion=entropy, max_depth=7, n_estimators=200..........
# [CV 3/5; 56/72] END criterion=entropy, max_depth=7, n_estimators=200;, score=0.892 total time=   0.2s
# [CV 4/5; 56/72] START criterion=entropy, max_depth=7, n_estimators=200..........
# [CV 4/5; 56/72] END criterion=entropy, max_depth=7, n_estimators=200;, score=0.870 total time=   0.2s
# [CV 5/5; 56/72] START criterion=entropy, max_depth=7, n_estimators=200..........
# [CV 5/5; 56/72] END criterion=entropy, max_depth=7, n_estimators=200;, score=0.853 total time=   0.3s
# [CV 1/5; 57/72] START criterion=entropy, max_depth=7, n_estimators=250..........
# [CV 1/5; 57/72] END criterion=entropy, max_depth=7, n_estimators=250;, score=0.863 total time=   0.3s
# [CV 2/5; 57/72] START criterion=entropy, max_depth=7, n_estimators=250..........
# [CV 2/5; 57/72] END criterion=entropy, max_depth=7, n_estimators=250;, score=0.870 total time=   0.3s
# [CV 3/5; 57/72] START criterion=entropy, max_depth=7, n_estimators=250..........
# [CV 3/5; 57/72] END criterion=entropy, max_depth=7, n_estimators=250;, score=0.902 total time=   0.3s
# [CV 4/5; 57/72] START criterion=entropy, max_depth=7, n_estimators=250..........
# [CV 4/5; 57/72] END criterion=entropy, max_depth=7, n_estimators=250;, score=0.845 total time=   0.3s
# [CV 5/5; 57/72] START criterion=entropy, max_depth=7, n_estimators=250..........
# [CV 5/5; 57/72] END criterion=entropy, max_depth=7, n_estimators=250;, score=0.865 total time=   0.3s
# [CV 1/5; 58/72] START criterion=entropy, max_depth=7, n_estimators=300..........
# [CV 1/5; 58/72] END criterion=entropy, max_depth=7, n_estimators=300;, score=0.850 total time=   0.4s
# [CV 2/5; 58/72] START criterion=entropy, max_depth=7, n_estimators=300..........
# [CV 2/5; 58/72] END criterion=entropy, max_depth=7, n_estimators=300;, score=0.858 total time=   0.4s
# [CV 3/5; 58/72] START criterion=entropy, max_depth=7, n_estimators=300..........
# [CV 3/5; 58/72] END criterion=entropy, max_depth=7, n_estimators=300;, score=0.877 total time=   0.5s
# [CV 4/5; 58/72] START criterion=entropy, max_depth=7, n_estimators=300..........
# [CV 4/5; 58/72] END criterion=entropy, max_depth=7, n_estimators=300;, score=0.855 total time=   0.4s
# [CV 5/5; 58/72] START criterion=entropy, max_depth=7, n_estimators=300..........
# [CV 5/5; 58/72] END criterion=entropy, max_depth=7, n_estimators=300;, score=0.853 total time=   0.4s
# [CV 1/5; 59/72] START criterion=entropy, max_depth=7, n_estimators=400..........
# [CV 1/5; 59/72] END criterion=entropy, max_depth=7, n_estimators=400;, score=0.870 total time=   0.7s
# [CV 2/5; 59/72] START criterion=entropy, max_depth=7, n_estimators=400..........
# [CV 2/5; 59/72] END criterion=entropy, max_depth=7, n_estimators=400;, score=0.863 total time=   0.6s
# [CV 3/5; 59/72] START criterion=entropy, max_depth=7, n_estimators=400..........
# [CV 3/5; 59/72] END criterion=entropy, max_depth=7, n_estimators=400;, score=0.895 total time=   0.5s
# [CV 4/5; 59/72] START criterion=entropy, max_depth=7, n_estimators=400..........
# [CV 4/5; 59/72] END criterion=entropy, max_depth=7, n_estimators=400;, score=0.858 total time=   0.5s
# [CV 5/5; 59/72] START criterion=entropy, max_depth=7, n_estimators=400..........
# [CV 5/5; 59/72] END criterion=entropy, max_depth=7, n_estimators=400;, score=0.845 total time=   0.5s
# [CV 1/5; 60/72] START criterion=entropy, max_depth=7, n_estimators=500..........
# [CV 1/5; 60/72] END criterion=entropy, max_depth=7, n_estimators=500;, score=0.860 total time=   0.6s
# [CV 2/5; 60/72] START criterion=entropy, max_depth=7, n_estimators=500..........
# [CV 2/5; 60/72] END criterion=entropy, max_depth=7, n_estimators=500;, score=0.868 total time=   0.7s
# [CV 3/5; 60/72] START criterion=entropy, max_depth=7, n_estimators=500..........
# [CV 3/5; 60/72] END criterion=entropy, max_depth=7, n_estimators=500;, score=0.887 total time=   0.6s
# [CV 4/5; 60/72] START criterion=entropy, max_depth=7, n_estimators=500..........
# [CV 4/5; 60/72] END criterion=entropy, max_depth=7, n_estimators=500;, score=0.863 total time=   0.6s
# [CV 5/5; 60/72] START criterion=entropy, max_depth=7, n_estimators=500..........
# [CV 5/5; 60/72] END criterion=entropy, max_depth=7, n_estimators=500;, score=0.858 total time=   0.6s
# [CV 1/5; 61/72] START criterion=entropy, max_depth=11, n_estimators=100.........
# [CV 1/5; 61/72] END criterion=entropy, max_depth=11, n_estimators=100;, score=0.880 total time=   0.1s
# [CV 2/5; 61/72] START criterion=entropy, max_depth=11, n_estimators=100.........
# [CV 2/5; 61/72] END criterion=entropy, max_depth=11, n_estimators=100;, score=0.897 total time=   0.1s
# [CV 3/5; 61/72] START criterion=entropy, max_depth=11, n_estimators=100.........
# [CV 3/5; 61/72] END criterion=entropy, max_depth=11, n_estimators=100;, score=0.895 total time=   0.1s
# [CV 4/5; 61/72] START criterion=entropy, max_depth=11, n_estimators=100.........
# [CV 4/5; 61/72] END criterion=entropy, max_depth=11, n_estimators=100;, score=0.865 total time=   0.2s
# [CV 5/5; 61/72] START criterion=entropy, max_depth=11, n_estimators=100.........
# [CV 5/5; 61/72] END criterion=entropy, max_depth=11, n_estimators=100;, score=0.875 total time=   0.1s
# [CV 1/5; 62/72] START criterion=entropy, max_depth=11, n_estimators=200.........
# [CV 1/5; 62/72] END criterion=entropy, max_depth=11, n_estimators=200;, score=0.885 total time=   0.3s
# [CV 2/5; 62/72] START criterion=entropy, max_depth=11, n_estimators=200.........
# [CV 2/5; 62/72] END criterion=entropy, max_depth=11, n_estimators=200;, score=0.880 total time=   0.3s
# [CV 3/5; 62/72] START criterion=entropy, max_depth=11, n_estimators=200.........
# [CV 3/5; 62/72] END criterion=entropy, max_depth=11, n_estimators=200;, score=0.910 total time=   0.3s
# [CV 4/5; 62/72] START criterion=entropy, max_depth=11, n_estimators=200.........
# [CV 4/5; 62/72] END criterion=entropy, max_depth=11, n_estimators=200;, score=0.868 total time=   0.3s
# [CV 5/5; 62/72] START criterion=entropy, max_depth=11, n_estimators=200.........
# [CV 5/5; 62/72] END criterion=entropy, max_depth=11, n_estimators=200;, score=0.860 total time=   0.3s
# [CV 1/5; 63/72] START criterion=entropy, max_depth=11, n_estimators=250.........
# [CV 1/5; 63/72] END criterion=entropy, max_depth=11, n_estimators=250;, score=0.873 total time=   0.3s
# [CV 2/5; 63/72] START criterion=entropy, max_depth=11, n_estimators=250.........
# [CV 2/5; 63/72] END criterion=entropy, max_depth=11, n_estimators=250;, score=0.890 total time=   0.3s
# [CV 3/5; 63/72] START criterion=entropy, max_depth=11, n_estimators=250.........
# [CV 3/5; 63/72] END criterion=entropy, max_depth=11, n_estimators=250;, score=0.902 total time=   0.3s
# [CV 4/5; 63/72] START criterion=entropy, max_depth=11, n_estimators=250.........
# [CV 4/5; 63/72] END criterion=entropy, max_depth=11, n_estimators=250;, score=0.870 total time=   0.4s
# [CV 5/5; 63/72] START criterion=entropy, max_depth=11, n_estimators=250.........
# [CV 5/5; 63/72] END criterion=entropy, max_depth=11, n_estimators=250;, score=0.865 total time=   0.4s
# [CV 1/5; 64/72] START criterion=entropy, max_depth=11, n_estimators=300.........
# [CV 1/5; 64/72] END criterion=entropy, max_depth=11, n_estimators=300;, score=0.885 total time=   0.4s
# [CV 2/5; 64/72] START criterion=entropy, max_depth=11, n_estimators=300.........
# [CV 2/5; 64/72] END criterion=entropy, max_depth=11, n_estimators=300;, score=0.882 total time=   0.5s
# [CV 3/5; 64/72] START criterion=entropy, max_depth=11, n_estimators=300.........
# [CV 3/5; 64/72] END criterion=entropy, max_depth=11, n_estimators=300;, score=0.910 total time=   0.5s
# [CV 4/5; 64/72] START criterion=entropy, max_depth=11, n_estimators=300.........
# [CV 4/5; 64/72] END criterion=entropy, max_depth=11, n_estimators=300;, score=0.868 total time=   0.4s
# [CV 5/5; 64/72] START criterion=entropy, max_depth=11, n_estimators=300.........
# [CV 5/5; 64/72] END criterion=entropy, max_depth=11, n_estimators=300;, score=0.868 total time=   0.4s
# [CV 1/5; 65/72] START criterion=entropy, max_depth=11, n_estimators=400.........
# [CV 1/5; 65/72] END criterion=entropy, max_depth=11, n_estimators=400;, score=0.885 total time=   0.7s
# [CV 2/5; 65/72] START criterion=entropy, max_depth=11, n_estimators=400.........
# [CV 2/5; 65/72] END criterion=entropy, max_depth=11, n_estimators=400;, score=0.892 total time=   0.6s
# [CV 3/5; 65/72] START criterion=entropy, max_depth=11, n_estimators=400.........
# [CV 3/5; 65/72] END criterion=entropy, max_depth=11, n_estimators=400;, score=0.902 total time=   0.6s
# [CV 4/5; 65/72] START criterion=entropy, max_depth=11, n_estimators=400.........
# [CV 4/5; 65/72] END criterion=entropy, max_depth=11, n_estimators=400;, score=0.875 total time=   0.6s
# [CV 5/5; 65/72] START criterion=entropy, max_depth=11, n_estimators=400.........
# [CV 5/5; 65/72] END criterion=entropy, max_depth=11, n_estimators=400;, score=0.870 total time=   0.6s
# [CV 1/5; 66/72] START criterion=entropy, max_depth=11, n_estimators=500.........
# [CV 1/5; 66/72] END criterion=entropy, max_depth=11, n_estimators=500;, score=0.885 total time=   0.7s
# [CV 2/5; 66/72] START criterion=entropy, max_depth=11, n_estimators=500.........
# [CV 2/5; 66/72] END criterion=entropy, max_depth=11, n_estimators=500;, score=0.895 total time=   0.6s
# [CV 3/5; 66/72] START criterion=entropy, max_depth=11, n_estimators=500.........
# [CV 3/5; 66/72] END criterion=entropy, max_depth=11, n_estimators=500;, score=0.905 total time=   0.7s
# [CV 4/5; 66/72] START criterion=entropy, max_depth=11, n_estimators=500.........
# [CV 4/5; 66/72] END criterion=entropy, max_depth=11, n_estimators=500;, score=0.870 total time=   0.7s
# [CV 5/5; 66/72] START criterion=entropy, max_depth=11, n_estimators=500.........
# [CV 5/5; 66/72] END criterion=entropy, max_depth=11, n_estimators=500;, score=0.873 total time=   0.7s
# [CV 1/5; 67/72] START criterion=entropy, max_depth=15, n_estimators=100.........
# [CV 1/5; 67/72] END criterion=entropy, max_depth=15, n_estimators=100;, score=0.875 total time=   0.1s
# [CV 2/5; 67/72] START criterion=entropy, max_depth=15, n_estimators=100.........
# [CV 2/5; 67/72] END criterion=entropy, max_depth=15, n_estimators=100;, score=0.880 total time=   0.1s
# [CV 3/5; 67/72] START criterion=entropy, max_depth=15, n_estimators=100.........
# [CV 3/5; 67/72] END criterion=entropy, max_depth=15, n_estimators=100;, score=0.910 total time=   0.1s
# [CV 4/5; 67/72] START criterion=entropy, max_depth=15, n_estimators=100.........
# [CV 4/5; 67/72] END criterion=entropy, max_depth=15, n_estimators=100;, score=0.853 total time=   0.1s
# [CV 5/5; 67/72] START criterion=entropy, max_depth=15, n_estimators=100.........
# [CV 5/5; 67/72] END criterion=entropy, max_depth=15, n_estimators=100;, score=0.873 total time=   0.1s
# [CV 1/5; 68/72] START criterion=entropy, max_depth=15, n_estimators=200.........
# [CV 1/5; 68/72] END criterion=entropy, max_depth=15, n_estimators=200;, score=0.877 total time=   0.3s
# [CV 2/5; 68/72] START criterion=entropy, max_depth=15, n_estimators=200.........
# [CV 2/5; 68/72] END criterion=entropy, max_depth=15, n_estimators=200;, score=0.890 total time=   0.3s
# [CV 3/5; 68/72] START criterion=entropy, max_depth=15, n_estimators=200.........
# [CV 3/5; 68/72] END criterion=entropy, max_depth=15, n_estimators=200;, score=0.895 total time=   0.3s
# [CV 4/5; 68/72] START criterion=entropy, max_depth=15, n_estimators=200.........
# [CV 4/5; 68/72] END criterion=entropy, max_depth=15, n_estimators=200;, score=0.875 total time=   0.3s
# [CV 5/5; 68/72] START criterion=entropy, max_depth=15, n_estimators=200.........
# [CV 5/5; 68/72] END criterion=entropy, max_depth=15, n_estimators=200;, score=0.873 total time=   0.3s
# [CV 1/5; 69/72] START criterion=entropy, max_depth=15, n_estimators=250.........
# [CV 1/5; 69/72] END criterion=entropy, max_depth=15, n_estimators=250;, score=0.882 total time=   0.4s
# [CV 2/5; 69/72] START criterion=entropy, max_depth=15, n_estimators=250.........
# [CV 2/5; 69/72] END criterion=entropy, max_depth=15, n_estimators=250;, score=0.895 total time=   0.4s
# [CV 3/5; 69/72] START criterion=entropy, max_depth=15, n_estimators=250.........
# [CV 3/5; 69/72] END criterion=entropy, max_depth=15, n_estimators=250;, score=0.897 total time=   0.5s
# [CV 4/5; 69/72] START criterion=entropy, max_depth=15, n_estimators=250.........
# [CV 4/5; 69/72] END criterion=entropy, max_depth=15, n_estimators=250;, score=0.868 total time=   0.4s
# [CV 5/5; 69/72] START criterion=entropy, max_depth=15, n_estimators=250.........
# [CV 5/5; 69/72] END criterion=entropy, max_depth=15, n_estimators=250;, score=0.873 total time=   0.4s
# [CV 1/5; 70/72] START criterion=entropy, max_depth=15, n_estimators=300.........
# [CV 1/5; 70/72] END criterion=entropy, max_depth=15, n_estimators=300;, score=0.892 total time=   0.6s
# [CV 2/5; 70/72] START criterion=entropy, max_depth=15, n_estimators=300.........
# [CV 2/5; 70/72] END criterion=entropy, max_depth=15, n_estimators=300;, score=0.892 total time=   0.4s
# [CV 3/5; 70/72] START criterion=entropy, max_depth=15, n_estimators=300.........
# [CV 3/5; 70/72] END criterion=entropy, max_depth=15, n_estimators=300;, score=0.905 total time=   0.4s
# [CV 4/5; 70/72] START criterion=entropy, max_depth=15, n_estimators=300.........
# [CV 4/5; 70/72] END criterion=entropy, max_depth=15, n_estimators=300;, score=0.870 total time=   0.4s
# [CV 5/5; 70/72] START criterion=entropy, max_depth=15, n_estimators=300.........
# [CV 5/5; 70/72] END criterion=entropy, max_depth=15, n_estimators=300;, score=0.882 total time=   0.5s
# [CV 1/5; 71/72] START criterion=entropy, max_depth=15, n_estimators=400.........
# [CV 1/5; 71/72] END criterion=entropy, max_depth=15, n_estimators=400;, score=0.885 total time=   0.6s
# [CV 2/5; 71/72] START criterion=entropy, max_depth=15, n_estimators=400.........
# [CV 2/5; 71/72] END criterion=entropy, max_depth=15, n_estimators=400;, score=0.890 total time=   0.5s
# [CV 3/5; 71/72] START criterion=entropy, max_depth=15, n_estimators=400.........
# [CV 3/5; 71/72] END criterion=entropy, max_depth=15, n_estimators=400;, score=0.902 total time=   0.6s
# [CV 4/5; 71/72] START criterion=entropy, max_depth=15, n_estimators=400.........
# [CV 4/5; 71/72] END criterion=entropy, max_depth=15, n_estimators=400;, score=0.870 total time=   0.5s
# [CV 5/5; 71/72] START criterion=entropy, max_depth=15, n_estimators=400.........
# [CV 5/5; 71/72] END criterion=entropy, max_depth=15, n_estimators=400;, score=0.870 total time=   0.5s
# [CV 1/5; 72/72] START criterion=entropy, max_depth=15, n_estimators=500.........
# [CV 1/5; 72/72] END criterion=entropy, max_depth=15, n_estimators=500;, score=0.880 total time=   0.7s
# [CV 2/5; 72/72] START criterion=entropy, max_depth=15, n_estimators=500.........
# [CV 2/5; 72/72] END criterion=entropy, max_depth=15, n_estimators=500;, score=0.882 total time=   0.7s
# [CV 3/5; 72/72] START criterion=entropy, max_depth=15, n_estimators=500.........
# [CV 3/5; 72/72] END criterion=entropy, max_depth=15, n_estimators=500;, score=0.907 total time=   0.7s
# [CV 4/5; 72/72] START criterion=entropy, max_depth=15, n_estimators=500.........
# [CV 4/5; 72/72] END criterion=entropy, max_depth=15, n_estimators=500;, score=0.873 total time=   0.7s
# [CV 5/5; 72/72] START criterion=entropy, max_depth=15, n_estimators=500.........
# [CV 5/5; 72/72] END criterion=entropy, max_depth=15, n_estimators=500;, score=0.875 total time=   0.7s
# Best score: 0.8885

# %%
print("Best parameters set:")
best_parameters = model.best_estimator_.get_params()
for param_name in sorted(param_grid.keys()):
    print(f"\t{param_name}: {best_parameters[param_name]}")
# Out:
# Best parameters set:
# 	criterion: entropy
# 	max_depth: 15
# 	n_estimators: 300

# %% [markdown]
# ### Random search

# %% [markdown]
# - we randomly select a combination of parameters and calculate the cross-validation score.
# - The time consumed here is less than grid search because we do not evaluate over all different combinations of parameters.

# %%
# define a grid of parameters
 # this can be a dictionary or a list of
 # dictionaries
param_grid_random = {
"n_estimators": np.arange(100, 1500, 100),
"max_depth": np.arange(1, 31),
"criterion": ["gini", "entropy"]
}

# %%
 # initialize random search
 # estimator is the model that we have defined
 # param_distributions is the grid/distribution of parameters
 # we use accuracy as our metric. you can define your own
 # higher value of verbose implies a lot of details are printed
 # cv=5 means that we are using 5 fold cv (not stratified)
 # n_iter is the number of iterations we want
 # if param_distributions has all the values as list,
 # random search will be done by sampling without replacement
 # if any of the parameters come from a distribution,
 # random search uses sampling with replacement
model_random = model_selection.RandomizedSearchCV(
 estimator=classifier, 
 param_distributions=param_grid_random,
 n_iter=20,
 scoring="accuracy",
 verbose=10, 
 n_jobs=1,
 cv=5
 )

# %%
# fit the model and extract best score
model_random.fit(X, y)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [CV 1/5; 1/20] START criterion=gini, max_depth=10, n_estimators=700.............
# [CV 1/5; 1/20] END criterion=gini, max_depth=10, n_estimators=700;, score=0.875 total time=   7.6s
# [CV 2/5; 1/20] START criterion=gini, max_depth=10, n_estimators=700.............
# [CV 2/5; 1/20] END criterion=gini, max_depth=10, n_estimators=700;, score=0.887 total time=   1.5s
# [CV 3/5; 1/20] START criterion=gini, max_depth=10, n_estimators=700.............
# [CV 3/5; 1/20] END criterion=gini, max_depth=10, n_estimators=700;, score=0.895 total time=   1.0s
# [CV 4/5; 1/20] START criterion=gini, max_depth=10, n_estimators=700.............
# [CV 4/5; 1/20] END criterion=gini, max_depth=10, n_estimators=700;, score=0.870 total time=   1.2s
# [CV 5/5; 1/20] START criterion=gini, max_depth=10, n_estimators=700.............
# [CV 5/5; 1/20] END criterion=gini, max_depth=10, n_estimators=700;, score=0.860 total time=   1.1s
# [CV 1/5; 2/20] START criterion=gini, max_depth=21, n_estimators=800.............
# [CV 1/5; 2/20] END criterion=gini, max_depth=21, n_estimators=800;, score=0.887 total time=   1.0s
# [CV 2/5; 2/20] START criterion=gini, max_depth=21, n_estimators=800.............
# [CV 2/5; 2/20] END criterion=gini, max_depth=21, n_estimators=800;, score=0.892 total time=   1.1s
# [CV 3/5; 2/20] START criterion=gini, max_depth=21, n_estimators=800.............
# [CV 3/5; 2/20] END criterion=gini, max_depth=21, n_estimators=800;, score=0.897 total time=   1.0s
# [CV 4/5; 2/20] START criterion=gini, max_depth=21, n_estimators=800.............
# [CV 4/5; 2/20] END criterion=gini, max_depth=21, n_estimators=800;, score=0.875 total time=   1.0s
# [CV 5/5; 2/20] START criterion=gini, max_depth=21, n_estimators=800.............
# [CV 5/5; 2/20] END criterion=gini, max_depth=21, n_estimators=800;, score=0.870 total time=   0.9s
# [CV 1/5; 3/20] START criterion=gini, max_depth=8, n_estimators=1400.............
# [CV 1/5; 3/20] END criterion=gini, max_depth=8, n_estimators=1400;, score=0.870 total time=   1.6s
# [CV 2/5; 3/20] START criterion=gini, max_depth=8, n_estimators=1400.............
# [CV 2/5; 3/20] END criterion=gini, max_depth=8, n_estimators=1400;, score=0.873 total time=   1.4s
# [CV 3/5; 3/20] START criterion=gini, max_depth=8, n_estimators=1400.............
# [CV 3/5; 3/20] END criterion=gini, max_depth=8, n_estimators=1400;, score=0.887 total time=   1.6s
# [CV 4/5; 3/20] START criterion=gini, max_depth=8, n_estimators=1400.............
# [CV 4/5; 3/20] END criterion=gini, max_depth=8, n_estimators=1400;, score=0.855 total time=   1.4s
# [CV 5/5; 3/20] START criterion=gini, max_depth=8, n_estimators=1400.............
# [CV 5/5; 3/20] END criterion=gini, max_depth=8, n_estimators=1400;, score=0.858 total time=   1.9s
# [CV 1/5; 4/20] START criterion=gini, max_depth=18, n_estimators=400.............
# [CV 1/5; 4/20] END criterion=gini, max_depth=18, n_estimators=400;, score=0.880 total time=   0.5s
# [CV 2/5; 4/20] START criterion=gini, max_depth=18, n_estimators=400.............
# [CV 2/5; 4/20] END criterion=gini, max_depth=18, n_estimators=400;, score=0.882 total time=   0.5s
# [CV 3/5; 4/20] START criterion=gini, max_depth=18, n_estimators=400.............
# [CV 3/5; 4/20] END criterion=gini, max_depth=18, n_estimators=400;, score=0.895 total time=   0.4s
# [CV 4/5; 4/20] START criterion=gini, max_depth=18, n_estimators=400.............
# [CV 4/5; 4/20] END criterion=gini, max_depth=18, n_estimators=400;, score=0.892 total time=   0.4s
# [CV 5/5; 4/20] START criterion=gini, max_depth=18, n_estimators=400.............
# [CV 5/5; 4/20] END criterion=gini, max_depth=18, n_estimators=400;, score=0.860 total time=   0.5s
# [CV 1/5; 5/20] START criterion=gini, max_depth=11, n_estimators=500.............
# [CV 1/5; 5/20] END criterion=gini, max_depth=11, n_estimators=500;, score=0.885 total time=   0.5s
# [CV 2/5; 5/20] START criterion=gini, max_depth=11, n_estimators=500.............
# [CV 2/5; 5/20] END criterion=gini, max_depth=11, n_estimators=500;, score=0.882 total time=   0.5s
# [CV 3/5; 5/20] START criterion=gini, max_depth=11, n_estimators=500.............
# [CV 3/5; 5/20] END criterion=gini, max_depth=11, n_estimators=500;, score=0.892 total time=   0.5s
# [CV 4/5; 5/20] START criterion=gini, max_depth=11, n_estimators=500.............
# [CV 4/5; 5/20] END criterion=gini, max_depth=11, n_estimators=500;, score=0.873 total time=   0.4s
# [CV 5/5; 5/20] START criterion=gini, max_depth=11, n_estimators=500.............
# [CV 5/5; 5/20] END criterion=gini, max_depth=11, n_estimators=500;, score=0.870 total time=   0.4s
# [CV 1/5; 6/20] START criterion=gini, max_depth=18, n_estimators=900.............
# [CV 1/5; 6/20] END criterion=gini, max_depth=18, n_estimators=900;, score=0.880 total time=   1.0s
# [CV 2/5; 6/20] START criterion=gini, max_depth=18, n_estimators=900.............
# [CV 2/5; 6/20] END criterion=gini, max_depth=18, n_estimators=900;, score=0.887 total time=   1.0s
# [CV 3/5; 6/20] START criterion=gini, max_depth=18, n_estimators=900.............
# [CV 3/5; 6/20] END criterion=gini, max_depth=18, n_estimators=900;, score=0.890 total time=   1.0s
# [CV 4/5; 6/20] START criterion=gini, max_depth=18, n_estimators=900.............
# [CV 4/5; 6/20] END criterion=gini, max_depth=18, n_estimators=900;, score=0.870 total time=   1.0s
# [CV 5/5; 6/20] START criterion=gini, max_depth=18, n_estimators=900.............
# [CV 5/5; 6/20] END criterion=gini, max_depth=18, n_estimators=900;, score=0.877 total time=   0.9s
# [CV 1/5; 7/20] START criterion=gini, max_depth=19, n_estimators=800.............
# [CV 1/5; 7/20] END criterion=gini, max_depth=19, n_estimators=800;, score=0.882 total time=   0.7s
# [CV 2/5; 7/20] START criterion=gini, max_depth=19, n_estimators=800.............
# [CV 2/5; 7/20] END criterion=gini, max_depth=19, n_estimators=800;, score=0.880 total time=   0.8s
# [CV 3/5; 7/20] START criterion=gini, max_depth=19, n_estimators=800.............
# [CV 3/5; 7/20] END criterion=gini, max_depth=19, n_estimators=800;, score=0.895 total time=   0.9s
# [CV 4/5; 7/20] START criterion=gini, max_depth=19, n_estimators=800.............
# [CV 4/5; 7/20] END criterion=gini, max_depth=19, n_estimators=800;, score=0.880 total time=   0.8s
# [CV 5/5; 7/20] START criterion=gini, max_depth=19, n_estimators=800.............
# [CV 5/5; 7/20] END criterion=gini, max_depth=19, n_estimators=800;, score=0.877 total time=   0.8s
# [CV 1/5; 8/20] START criterion=gini, max_depth=16, n_estimators=1400............
# [CV 1/5; 8/20] END criterion=gini, max_depth=16, n_estimators=1400;, score=0.875 total time=   1.4s
# [CV 2/5; 8/20] START criterion=gini, max_depth=16, n_estimators=1400............
# [CV 2/5; 8/20] END criterion=gini, max_depth=16, n_estimators=1400;, score=0.887 total time=   1.4s
# [CV 3/5; 8/20] START criterion=gini, max_depth=16, n_estimators=1400............
# [CV 3/5; 8/20] END criterion=gini, max_depth=16, n_estimators=1400;, score=0.897 total time=   1.3s
# [CV 4/5; 8/20] START criterion=gini, max_depth=16, n_estimators=1400............
# [CV 4/5; 8/20] END criterion=gini, max_depth=16, n_estimators=1400;, score=0.877 total time=   1.3s
# [CV 5/5; 8/20] START criterion=gini, max_depth=16, n_estimators=1400............
# [CV 5/5; 8/20] END criterion=gini, max_depth=16, n_estimators=1400;, score=0.860 total time=   1.3s
# [CV 1/5; 9/20] START criterion=gini, max_depth=12, n_estimators=900.............
# [CV 1/5; 9/20] END criterion=gini, max_depth=12, n_estimators=900;, score=0.877 total time=   0.9s
# [CV 2/5; 9/20] START criterion=gini, max_depth=12, n_estimators=900.............
# [CV 2/5; 9/20] END criterion=gini, max_depth=12, n_estimators=900;, score=0.887 total time=   1.0s
# [CV 3/5; 9/20] START criterion=gini, max_depth=12, n_estimators=900.............
# [CV 3/5; 9/20] END criterion=gini, max_depth=12, n_estimators=900;, score=0.892 total time=   0.9s
# [CV 4/5; 9/20] START criterion=gini, max_depth=12, n_estimators=900.............
# [CV 4/5; 9/20] END criterion=gini, max_depth=12, n_estimators=900;, score=0.870 total time=   0.9s
# [CV 5/5; 9/20] START criterion=gini, max_depth=12, n_estimators=900.............
# [CV 5/5; 9/20] END criterion=gini, max_depth=12, n_estimators=900;, score=0.870 total time=   0.9s
# [CV 1/5; 10/20] START criterion=gini, max_depth=21, n_estimators=300............
# [CV 1/5; 10/20] END criterion=gini, max_depth=21, n_estimators=300;, score=0.887 total time=   0.3s
# [CV 2/5; 10/20] START criterion=gini, max_depth=21, n_estimators=300............
# [CV 2/5; 10/20] END criterion=gini, max_depth=21, n_estimators=300;, score=0.877 total time=   0.3s
# [CV 3/5; 10/20] START criterion=gini, max_depth=21, n_estimators=300............
# [CV 3/5; 10/20] END criterion=gini, max_depth=21, n_estimators=300;, score=0.890 total time=   0.3s
# [CV 4/5; 10/20] START criterion=gini, max_depth=21, n_estimators=300............
# [CV 4/5; 10/20] END criterion=gini, max_depth=21, n_estimators=300;, score=0.873 total time=   0.3s
# [CV 5/5; 10/20] START criterion=gini, max_depth=21, n_estimators=300............
# [CV 5/5; 10/20] END criterion=gini, max_depth=21, n_estimators=300;, score=0.868 total time=   0.3s
# [CV 1/5; 11/20] START criterion=gini, max_depth=2, n_estimators=300.............
# [CV 1/5; 11/20] END criterion=gini, max_depth=2, n_estimators=300;, score=0.723 total time=   0.3s
# [CV 2/5; 11/20] START criterion=gini, max_depth=2, n_estimators=300.............
# [CV 2/5; 11/20] END criterion=gini, max_depth=2, n_estimators=300;, score=0.745 total time=   0.3s
# [CV 3/5; 11/20] START criterion=gini, max_depth=2, n_estimators=300.............
# [CV 3/5; 11/20] END criterion=gini, max_depth=2, n_estimators=300;, score=0.748 total time=   0.3s
# [CV 4/5; 11/20] START criterion=gini, max_depth=2, n_estimators=300.............
# [CV 4/5; 11/20] END criterion=gini, max_depth=2, n_estimators=300;, score=0.772 total time=   0.3s
# [CV 5/5; 11/20] START criterion=gini, max_depth=2, n_estimators=300.............
# [CV 5/5; 11/20] END criterion=gini, max_depth=2, n_estimators=300;, score=0.755 total time=   0.3s
# [CV 1/5; 12/20] START criterion=entropy, max_depth=28, n_estimators=200.........
# [CV 1/5; 12/20] END criterion=entropy, max_depth=28, n_estimators=200;, score=0.875 total time=   0.2s
# [CV 2/5; 12/20] START criterion=entropy, max_depth=28, n_estimators=200.........
# [CV 2/5; 12/20] END criterion=entropy, max_depth=28, n_estimators=200;, score=0.892 total time=   0.3s
# [CV 3/5; 12/20] START criterion=entropy, max_depth=28, n_estimators=200.........
# [CV 3/5; 12/20] END criterion=entropy, max_depth=28, n_estimators=200;, score=0.907 total time=   0.2s
# [CV 4/5; 12/20] START criterion=entropy, max_depth=28, n_estimators=200.........
# [CV 4/5; 12/20] END criterion=entropy, max_depth=28, n_estimators=200;, score=0.870 total time=   0.2s
# [CV 5/5; 12/20] START criterion=entropy, max_depth=28, n_estimators=200.........
# [CV 5/5; 12/20] END criterion=entropy, max_depth=28, n_estimators=200;, score=0.875 total time=   0.2s
# [CV 1/5; 13/20] START criterion=gini, max_depth=28, n_estimators=300............
# [CV 1/5; 13/20] END criterion=gini, max_depth=28, n_estimators=300;, score=0.882 total time=   0.3s
# [CV 2/5; 13/20] START criterion=gini, max_depth=28, n_estimators=300............
# [CV 2/5; 13/20] END criterion=gini, max_depth=28, n_estimators=300;, score=0.892 total time=   0.3s
# [CV 3/5; 13/20] START criterion=gini, max_depth=28, n_estimators=300............
# [CV 3/5; 13/20] END criterion=gini, max_depth=28, n_estimators=300;, score=0.892 total time=   0.3s
# [CV 4/5; 13/20] START criterion=gini, max_depth=28, n_estimators=300............
# [CV 4/5; 13/20] END criterion=gini, max_depth=28, n_estimators=300;, score=0.868 total time=   0.3s
# [CV 5/5; 13/20] START criterion=gini, max_depth=28, n_estimators=300............
# [CV 5/5; 13/20] END criterion=gini, max_depth=28, n_estimators=300;, score=0.873 total time=   0.3s
# [CV 1/5; 14/20] START criterion=entropy, max_depth=8, n_estimators=100..........
# [CV 1/5; 14/20] END criterion=entropy, max_depth=8, n_estimators=100;, score=0.860 total time=   0.1s
# [CV 2/5; 14/20] START criterion=entropy, max_depth=8, n_estimators=100..........
# [CV 2/5; 14/20] END criterion=entropy, max_depth=8, n_estimators=100;, score=0.880 total time=   0.1s
# [CV 3/5; 14/20] START criterion=entropy, max_depth=8, n_estimators=100..........
# [CV 3/5; 14/20] END criterion=entropy, max_depth=8, n_estimators=100;, score=0.895 total time=   0.1s
# [CV 4/5; 14/20] START criterion=entropy, max_depth=8, n_estimators=100..........
# [CV 4/5; 14/20] END criterion=entropy, max_depth=8, n_estimators=100;, score=0.865 total time=   0.1s
# [CV 5/5; 14/20] START criterion=entropy, max_depth=8, n_estimators=100..........
# [CV 5/5; 14/20] END criterion=entropy, max_depth=8, n_estimators=100;, score=0.865 total time=   0.1s
# [CV 1/5; 15/20] START criterion=gini, max_depth=9, n_estimators=100.............
# [CV 1/5; 15/20] END criterion=gini, max_depth=9, n_estimators=100;, score=0.870 total time=   0.1s
# [CV 2/5; 15/20] START criterion=gini, max_depth=9, n_estimators=100.............
# [CV 2/5; 15/20] END criterion=gini, max_depth=9, n_estimators=100;, score=0.873 total time=   0.1s
# [CV 3/5; 15/20] START criterion=gini, max_depth=9, n_estimators=100.............
# [CV 3/5; 15/20] END criterion=gini, max_depth=9, n_estimators=100;, score=0.912 total time=   0.1s
# [CV 4/5; 15/20] START criterion=gini, max_depth=9, n_estimators=100.............
# [CV 4/5; 15/20] END criterion=gini, max_depth=9, n_estimators=100;, score=0.877 total time=   0.1s
# [CV 5/5; 15/20] START criterion=gini, max_depth=9, n_estimators=100.............
# [CV 5/5; 15/20] END criterion=gini, max_depth=9, n_estimators=100;, score=0.845 total time=   0.1s
# [CV 1/5; 16/20] START criterion=entropy, max_depth=6, n_estimators=1000.........
# [CV 1/5; 16/20] END criterion=entropy, max_depth=6, n_estimators=1000;, score=0.848 total time=   0.7s
# [CV 2/5; 16/20] START criterion=entropy, max_depth=6, n_estimators=1000.........
# [CV 2/5; 16/20] END criterion=entropy, max_depth=6, n_estimators=1000;, score=0.843 total time=   0.8s
# [CV 3/5; 16/20] START criterion=entropy, max_depth=6, n_estimators=1000.........
# [CV 3/5; 16/20] END criterion=entropy, max_depth=6, n_estimators=1000;, score=0.887 total time=   0.7s
# [CV 4/5; 16/20] START criterion=entropy, max_depth=6, n_estimators=1000.........
# [CV 4/5; 16/20] END criterion=entropy, max_depth=6, n_estimators=1000;, score=0.850 total time=   0.7s
# [CV 5/5; 16/20] START criterion=entropy, max_depth=6, n_estimators=1000.........
# [CV 5/5; 16/20] END criterion=entropy, max_depth=6, n_estimators=1000;, score=0.850 total time=   0.8s
# [CV 1/5; 17/20] START criterion=entropy, max_depth=1, n_estimators=300..........
# [CV 1/5; 17/20] END criterion=entropy, max_depth=1, n_estimators=300;, score=0.537 total time=   0.3s
# [CV 2/5; 17/20] START criterion=entropy, max_depth=1, n_estimators=300..........
# [CV 2/5; 17/20] END criterion=entropy, max_depth=1, n_estimators=300;, score=0.545 total time=   0.3s
# [CV 3/5; 17/20] START criterion=entropy, max_depth=1, n_estimators=300..........
# [CV 3/5; 17/20] END criterion=entropy, max_depth=1, n_estimators=300;, score=0.540 total time=   0.3s
# [CV 4/5; 17/20] START criterion=entropy, max_depth=1, n_estimators=300..........
# [CV 4/5; 17/20] END criterion=entropy, max_depth=1, n_estimators=300;, score=0.537 total time=   0.3s
# [CV 5/5; 17/20] START criterion=entropy, max_depth=1, n_estimators=300..........
# [CV 5/5; 17/20] END criterion=entropy, max_depth=1, n_estimators=300;, score=0.552 total time=   0.3s
# [CV 1/5; 18/20] START criterion=entropy, max_depth=30, n_estimators=1400........
# [CV 1/5; 18/20] END criterion=entropy, max_depth=30, n_estimators=1400;, score=0.882 total time=   1.3s
# [CV 2/5; 18/20] START criterion=entropy, max_depth=30, n_estimators=1400........
# [CV 2/5; 18/20] END criterion=entropy, max_depth=30, n_estimators=1400;, score=0.900 total time=   1.4s
# [CV 3/5; 18/20] START criterion=entropy, max_depth=30, n_estimators=1400........
# [CV 3/5; 18/20] END criterion=entropy, max_depth=30, n_estimators=1400;, score=0.910 total time=   1.3s
# [CV 4/5; 18/20] START criterion=entropy, max_depth=30, n_estimators=1400........
# [CV 4/5; 18/20] END criterion=entropy, max_depth=30, n_estimators=1400;, score=0.873 total time=   1.4s
# [CV 5/5; 18/20] START criterion=entropy, max_depth=30, n_estimators=1400........
# [CV 5/5; 18/20] END criterion=entropy, max_depth=30, n_estimators=1400;, score=0.870 total time=   1.4s
# [CV 1/5; 19/20] START criterion=gini, max_depth=14, n_estimators=1300...........
# [CV 1/5; 19/20] END criterion=gini, max_depth=14, n_estimators=1300;, score=0.880 total time=   1.3s
# [CV 2/5; 19/20] START criterion=gini, max_depth=14, n_estimators=1300...........
# [CV 2/5; 19/20] END criterion=gini, max_depth=14, n_estimators=1300;, score=0.892 total time=   1.4s
# [CV 3/5; 19/20] START criterion=gini, max_depth=14, n_estimators=1300...........
# [CV 3/5; 19/20] END criterion=gini, max_depth=14, n_estimators=1300;, score=0.900 total time=   1.4s
# [CV 4/5; 19/20] START criterion=gini, max_depth=14, n_estimators=1300...........
# [CV 4/5; 19/20] END criterion=gini, max_depth=14, n_estimators=1300;, score=0.873 total time=   1.5s
# [CV 5/5; 19/20] START criterion=gini, max_depth=14, n_estimators=1300...........
# [CV 5/5; 19/20] END criterion=gini, max_depth=14, n_estimators=1300;, score=0.870 total time=   1.4s
# [CV 1/5; 20/20] START criterion=entropy, max_depth=6, n_estimators=400..........
# [CV 1/5; 20/20] END criterion=entropy, max_depth=6, n_estimators=400;, score=0.843 total time=   0.3s
# [CV 2/5; 20/20] START criterion=entropy, max_depth=6, n_estimators=400..........
# [CV 2/5; 20/20] END criterion=entropy, max_depth=6, n_estimators=400;, score=0.853 total time=   0.3s
# [CV 3/5; 20/20] START criterion=entropy, max_depth=6, n_estimators=400..........
# [CV 3/5; 20/20] END criterion=entropy, max_depth=6, n_estimators=400;, score=0.870 total time=   0.3s
# [CV 4/5; 20/20] START criterion=entropy, max_depth=6, n_estimators=400..........
# [CV 4/5; 20/20] END criterion=entropy, max_depth=6, n_estimators=400;, score=0.848 total time=   0.4s
# [CV 5/5; 20/20] START criterion=entropy, max_depth=6, n_estimators=400..........
# [CV 5/5; 20/20] END criterion=entropy, max_depth=6, n_estimators=400;, score=0.858 total time=   0.3s
# Best score: 0.8869999999999999

# %%
print(f"Best score: {model_random.best_score_}")
print("Best parameters set:")
best_parameters = model_random.best_estimator_.get_params()
for param_name in sorted(param_grid_random.keys()):
 print(f"\t{param_name}: {best_parameters[param_name]}")
# Out:
# Best score: 0.8869999999999999
# Best parameters set:
# 	criterion: entropy
# 	max_depth: 30
# 	n_estimators: 1400

# %% [markdown]
# - When we go into advanced hyperparameter optimization techniques, we can take a look at minimization of functions using different kinds of minimization algorithms.
#
# - This can be achieved by using many minimization functions such as
#     - `downhill simplex algorithm`, `Nelder-Mead optimization`,
#     - using a `Bayesian technique` with Gaussian process for finding optimal parameters.
#     - By using a `genetic algorithm`.

# %% [markdown]
# ##### Gaussian process

# %% [markdown]
# - These kinds of algorithms need a function they can optimize. Most of the time, it’s about the minimization of
# this function, like we minimize loss.
#
# - Using Bayesian optimization with gaussian process can be accomplished by using gp_minimize
# function from scikit-optimize (skopt) library

# %%
! pip install scikit-optimize
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting scikit-optimize
#   Using cached scikit_optimize-0.9.0-py2.py3-none-any.whl (100 kB)
# Requirement already satisfied: joblib>=0.11 in c:\users\lenovo\appdata\roaming\python\python39\site-packages (from scikit-optimize) (1.2.0)
# Requirement already satisfied: numpy>=1.13.3 in c:\users\lenovo\appdata\roaming\python\python39\site-packages (from scikit-optimize) (1.24.2)
# Requirement already satisfied: scipy>=0.19.1 in c:\users\lenovo\appdata\roaming\python\python39\site-packages (from scikit-optimize) (1.10.1)
# Collecting pyaml>=16.9
#   Downloading pyaml-23.5.9-py3-none-any.whl (17 kB)
# Requirement already satisfied: scikit-learn>=0.20.0 in c:\users\lenovo\appdata\roaming\python\python39\site-packages (from scikit-optimize) (1.2.2)
# Collecting PyYAML
#   Downloading PyYAML-6.0-cp39-cp39-win_amd64.whl (151 kB)
#      ------------------------------------ 151.6/151.6 KB 411.1 kB/s eta 0:00:00
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\lenovo\appdata\roaming\python\python39\site-packages (from scikit-learn>=0.20.0->scikit-optimize) (3.1.0)
# Installing collected packages: PyYAML, pyaml, scikit-optimize
# Successfully installed PyYAML-6.0 pyaml-23.5.9 scikit-optimize-0.9.0
# WARNING: You are using pip version 22.0.4; however, version 23.1.2 is available.
# You should consider upgrading via the 'C:\Program Files\Python39\python.exe -m pip install --upgrade pip' command.

# %%
import numpy as np
import pandas as pd
from functools import partial
from sklearn import ensemble
from sklearn import metrics
from sklearn import model_selection

from skopt import gp_minimize
from skopt import space

# %%
def optimize(params, param_names, x, y):
    """
    The main optimization function. 
    This function takes all the arguments from the search space
    and training features and targets. It then initializes
    the models by setting the chosen parameters and runs 
    cross-validation and returns a negative accuracy score
    :param params: list of params from gp_minimize
    :param param_names: list of param names. order is important!
    :param x: training data
    :param y: labels/targets
    :return: negative accuracy after 5 folds
    """

    # convert params to dictionary
    params = dict(zip(param_names, params))

    # initialize model with current parameters
    model = ensemble.RandomForestClassifier(**params)

    # initialize stratified k-fold
    kf = model_selection.StratifiedKFold(n_splits=5)

    # initialize accuracy list
    accuracies = []

    # loop over all folds
    for idx in kf.split(X=x, y=y):
        train_idx, test_idx = idx[0], idx[1]
        xtrain = x[train_idx]
        ytrain = y[train_idx]
        xtest = x[test_idx]
        ytest = y[test_idx]

        # fit model for current fold
        model.fit(xtrain, ytrain)

        #create predictions
        preds = model.predict(xtest)

        # calculate and append accuracy
        fold_accuracy = metrics.accuracy_score(
        ytest,
        preds
        )
        accuracies.append(fold_accuracy)

    # return negative accuracy
    return -1 * np.mean(accuracies)

# %%
# read the training data
data_df = pd.read_csv(r"C:\Users\lenovo\Desktop\Disha Github\Machine Learning Approaches\Machine-Learning\datasets\train.csv")

# %%
# features are all columns without price_range
 # note that there is no id column in this dataset
 # here we have training features
X = data_df.drop("price_range", axis=1).values
 # and the targets
y = data_df.price_range.values

# %%
# define a parameter space
param_space = [
 # max_depth is an integer between 3 and 10
 space.Integer(3, 15, name="max_depth"),
 # n_estimators is an integer between 50 and 1500
 space.Integer(100, 1500, name="n_estimators"),
 # criterion is a category. here we define list of categories
 space.Categorical(["gini", "entropy"], name="criterion"),
 # you can also have Real numbered space and define a 
 # distribution you want to pick it from
 space.Real(0.01, 1, prior="uniform", name="max_features")
 ]

# %%
param_space
# Out:
# [Integer(low=3, high=15, prior='uniform', transform='normalize'),
#  Integer(low=100, high=1500, prior='uniform', transform='normalize'),
#  Categorical(categories=('gini', 'entropy'), prior=None),
#  Real(low=0.01, high=1, prior='uniform', transform='normalize')]

# %%
# make a list of param names
 # this has to be same order as the search space
 # inside the main function
param_names = [
 "max_depth",
 "n_estimators",
 "criterion",
 "max_features"
 ]

# %%
# by using functools partial, i am creating a 
 # new function which has same parameters as the 
 # optimize function except for the fact that
 # only one param, i.e. the "params" parameter is
 # required. this is how gp_minimize expects the 
 # optimization function to be. you can get rid of this
 # by reading data inside the optimize function or by
 # defining the optimize function here.
optimization_function = partial(
 optimize,
 param_names=param_names,
 x=X,
 y=y
 )

# %%
# now we call gp_minimize from scikit-optimize
 # gp_minimize uses bayesian optimization for 
 # minimization of the optimization function.
 # we need a space of parameters, the function itself,
 # the number of calls/iterations we want to have

result = gp_minimize(   
 optimization_function,
 dimensions=param_space,
 n_calls=15,
 n_random_starts=10,
 verbose=10
 )
# Out:
# Iteration No: 1 started. Evaluating function at random point.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\lenovo\Desktop\Disha Github\Machine Learning Approaches\Machine-Learning\Hyperparameter_optimization.ipynb Cell 34 in <cell line: 7>()
#       <a href='vscode-notebook-cell:/c%3A/Users/lenovo/Desktop/Disha%20Github/Machine%20Learning%20Approaches/Machine-Learning/Hyperparameter_optimization.ipynb#X45sZmlsZQ%3D%3D?line=0'>1</a> # now we call gp_minimize from scikit-optimize
#       <a href='vscode-notebook-cell:/c%3A/Users/lenovo/Desktop/Disha%20Github/Machine%20Learning%20Approaches/Machine-Learning/Hyperparameter_optimization.ipynb#X45sZmlsZQ%3D%3D?line=1'>2</a>  # gp_minimize uses bayesian optimization for
#       <a href='vscode-notebook-cell:/c%3A/Users/lenovo/Desktop/Disha%20Github/Machine%20Learning%20Approaches/Machine-Learning/Hyperparameter_optimization.ipynb#X45sZmlsZQ%3D%3D?line=2'>3</a>  # minimization of the optimization function.
#       <a href='vscode-notebook-cell:/c%3A/Users/lenovo/Desktop/Disha%20Github/Machine%20Learning%20Approaches/Machine-Learning/Hyperparameter_optimization.ipynb#X45sZmlsZQ%3D%3D?line=3'>4</a>  # we need a space of parameters, the function itself,
#       <a href='vscode-notebook-cell:/c%3A/Users/lenovo/Desktop/Disha%20Github/Machine%20Learning%20Approaches/Machine-Learning/Hyperparameter_optimization.ipynb#X45sZmlsZQ%3D%3D?line=4'>5</a>  # the number of calls/iterations we want to have
# ----> <a href='vscode-notebook-cell:/c%3A/Users/lenovo/Desktop/Disha%20Github/Machine%20Learning%20Approaches/Machine-Learning/Hyperparameter_optimization.ipynb#X45sZmlsZQ%3D%3D?line=6'>7</a> result = gp_minimize(
#       <a href='vscode-notebook-cell:/c%3A/Users/lenovo/Desktop/Disha%20Github/Machine%20Learning%20Approaches/Machine-Learning/Hyperparameter_optimization.ipynb#X45sZmlsZQ%3D%3D?line=7'>8</a>  optimization_function,
#       <a href='vscode-notebook-cell:/c%3A/Users/lenovo/Desktop/Disha%20Github/Machine%20Learning%20Approaches/Machine-Learning/Hyperparameter_optimization.ipynb#X45sZmlsZQ%3D%3D?line=8'>9</a>  dimensions=param_space,
#      <a href='vscode-notebook-cell:/c%3A/Users/lenovo/Desktop/Disha%20Github/Machine%20Learning%20Approaches/Machine-Learning/Hyperparameter_optimization.ipynb#X45sZmlsZQ%3D%3D?line=9'>10</a>  base_estimator=None,
#      <a href='vscode-notebook-cell:/c%3A/Users/lenovo/Desktop/Disha%20Github/Machine%20Learning%20Approaches/Machine-Learning/Hyperparameter_optimization.ipynb#X45sZmlsZQ%3D%3D?line=10'>11</a>  n_calls=15,
#      <a href='vscode-notebook-cell:/c%3A/Users/lenovo/Desktop/Disha%20Github/Machine%20Learning%20Approaches/Machine-Learning/Hyperparameter_optimization.ipynb#X45sZmlsZQ%3D%3D?line=11'>12</a>  n_random_starts=10,
#      <a href='vscode-notebook-cell:/c%3A/Users/lenovo/Desktop/Disha%20Github/Machine%20Learning%20Approaches/Machine-Learning/Hyperparameter_optimization.ipynb#X45sZmlsZQ%3D%3D?line=12'>13</a>  verbose=10
#      <a href='vscode-notebook-cell:/c%3A/Users/lenovo/Desktop/Disha%20Github/Machine%20Learning%20Approaches/Machine-Learning/Hyperparameter_optimization.ipynb#X45sZmlsZQ%3D%3D?line=13'>14</a>  )
#
# File ~\AppData\Roaming\Python\Python39\site-packages\skopt\optimizer\gp.py:259, in gp_minimize(func, dimensions, base_estimator, n_calls, n_random_starts, n_initial_points, initial_point_generator, acq_func, acq_optimizer, x0, y0, random_state, verbose, callback, n_points, n_restarts_optimizer, xi, kappa, noise, n_jobs, model_queue_size)
#     254 if base_estimator is None:
#     255     base_estimator = cook_estimator(
#     256         "GP", space=space, random_state=rng.randint(0, np.iinfo(np.int32).max),
#     257         noise=noise)
# --> 259 return base_minimize(
#     260     func, space, base_estimator=base_estimator,
#     261     acq_func=acq_func,
#     262     xi=xi, kappa=kappa, acq_optimizer=acq_optimizer, n_calls=n_calls,
#     263     n_points=n_points, n_random_starts=n_random_starts,
#     264     n_initial_points=n_initial_points,
#     265     initial_point_generator=initial_point_generator,
#     266     n_restarts_optimizer=n_restarts_optimizer,
#     267     x0=x0, y0=y0, random_state=rng, verbose=verbose,
#     268     callback=callback, n_jobs=n_jobs, model_queue_size=model_queue_size)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\skopt\optimizer\base.py:298, in base_minimize(func, dimensions, base_estimator, n_calls, n_random_starts, n_initial_points, initial_point_generator, acq_func, acq_optimizer, x0, y0, random_state, verbose, callback, n_points, n_restarts_optimizer, xi, kappa, n_jobs, model_queue_size)
#     296 # Optimize
#     297 for n in range(n_calls):
# --> 298     next_x = optimizer.ask()
#     299     next_y = func(next_x)
#     300     result = optimizer.tell(next_x, next_y)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\skopt\optimizer\optimizer.py:367, in Optimizer.ask(self, n_points, strategy)
#     336 """Query point or multiple points at which objective should be evaluated.
#     337
#     338 n_points : int or None, default: None
#    (...)
#     364
#     365 """
#     366 if n_points is None:
# --> 367     return self._ask()
#     369 supported_strategies = ["cl_min", "cl_mean", "cl_max"]
#     371 if not (isinstance(n_points, int) and n_points > 0):
#
# File ~\AppData\Roaming\Python\Python39\site-packages\skopt\optimizer\optimizer.py:434, in Optimizer._ask(self)
#     430 if self._n_initial_points > 0 or self.base_estimator_ is None:
#     431     # this will not make a copy of `self.rng` and hence keep advancing
#     432     # our random state.
#     433     if self._initial_samples is None:
# --> 434         return self.space.rvs(random_state=self.rng)[0]
#     435     else:
#     436         # The samples are evaluated starting form initial_samples[0]
#     437         return self._initial_samples[
#     438             len(self._initial_samples) - self._n_initial_points]
#
# File ~\AppData\Roaming\Python\Python39\site-packages\skopt\space\space.py:900, in Space.rvs(self, n_samples, random_state)
#     897 columns = []
#     899 for dim in self.dimensions:
# --> 900     columns.append(dim.rvs(n_samples=n_samples, random_state=rng))
#     902 # Transpose
#     903 return _transpose_list_array(columns)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\skopt\space\space.py:158, in Dimension.rvs(self, n_samples, random_state)
#     156 rng = check_random_state(random_state)
#     157 samples = self._rvs.rvs(size=n_samples, random_state=rng)
# --> 158 return self.inverse_transform(samples)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\skopt\space\space.py:528, in Integer.inverse_transform(self, Xt)
#     523 """Inverse transform samples from the warped space back into the
#     524    original space.
#     525 """
#     526 # The concatenation of all transformed dimensions makes Xt to be
#     527 # of type float, hence the required cast back to int.
# --> 528 inv_transform = super(Integer, self).inverse_transform(Xt)
#     529 if isinstance(inv_transform, list):
#     530     inv_transform = np.array(inv_transform)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\skopt\space\space.py:168, in Dimension.inverse_transform(self, Xt)
#     164 def inverse_transform(self, Xt):
#     165     """Inverse transform samples from the warped space back into the
#     166        original space.
#     167     """
# --> 168     return self.transformer.inverse_transform(Xt)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\skopt\space\transformers.py:309, in Pipeline.inverse_transform(self, X)
#     307 def inverse_transform(self, X):
#     308     for transformer in self.transformers[::-1]:
# --> 309         X = transformer.inverse_transform(X)
#     310     return X
#
# File ~\AppData\Roaming\Python\Python39\site-packages\skopt\space\transformers.py:275, in Normalize.inverse_transform(self, X)
#     273 X_orig = X * (self.high - self.low) + self.low
#     274 if self.is_int:
# --> 275     return np.round(X_orig).astype(np.int)
#     276 return X_orig
#
# File ~\AppData\Roaming\Python\Python39\site-packages\numpy\__init__.py:305, in __getattr__(attr)
#     300     warnings.warn(
#     301         f"In the future `np.{attr}` will be defined as the "
#     302         "corresponding NumPy scalar.", FutureWarning, stacklevel=2)
#     304 if attr in __former_attrs__:
# --> 305     raise AttributeError(__former_attrs__[attr])
#     307 # Importing Tester requires importing all of UnitTest which is not a
#     308 # cheap import Since it is mainly used in test suits, we lazy import it
#     309 # here to save on the order of 10 ms of import time for most users
#     310 #
#     311 # The previous way Tester was imported also had a side effect of adding
#     312 # the full `numpy.testing` namespace
#     313 if attr == 'testing':
#
# AttributeError: module 'numpy' has no attribute 'int'.
# `np.int` was a deprecated alias for the builtin `int`. To avoid this error in existing code, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations

# %%
# create best params dict and print it
best_params = dict(
 zip(
 param_names,
 result.x
 )
 )
 print(best_params)

# %% [markdown]
# - Another useful library for hyperparameter optimization is `hyperopt`.
# - `hyperopt` uses Tree-structured Parzen Estimator (TPE) to find the most optimal parameters.

# %%
! pip install hyperopt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting hyperopt
#   Downloading hyperopt-0.2.7-py2.py3-none-any.whl (1.6 MB)
#      ---------------------------------------- 1.6/1.6 MB 8.4 MB/s eta 0:00:00
# Requirement already satisfied: scipy in c:\users\lenovo\appdata\roaming\python\python39\site-packages (from hyperopt) (1.10.1)
# Requirement already satisfied: six in c:\users\lenovo\appdata\roaming\python\python39\site-packages (from hyperopt) (1.16.0)
# Collecting networkx>=2.2
#   Downloading networkx-3.1-py3-none-any.whl (2.1 MB)
#      ---------------------------------------- 2.1/2.1 MB 26.4 MB/s eta 0:00:00
# Collecting py4j
#   Downloading py4j-0.10.9.7-py2.py3-none-any.whl (200 kB)
#      ---------------------------------------- 200.5/200.5 KB ? eta 0:00:00
# Collecting future
#   Downloading future-0.18.3.tar.gz (840 kB)
#      ------------------------------------- 840.9/840.9 KB 51.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting tqdm
#   Downloading tqdm-4.65.0-py3-none-any.whl (77 kB)
#      ---------------------------------------- 77.1/77.1 KB 4.2 MB/s eta 0:00:00
# Collecting cloudpickle
#   Downloading cloudpickle-2.2.1-py3-none-any.whl (25 kB)
# Requirement already satisfied: numpy in c:\users\lenovo\appdata\roaming\python\python39\site-packages (from hyperopt) (1.24.2)
# Requirement already satisfied: colorama in c:\users\lenovo\appdata\roaming\python\python39\site-packages (from tqdm->hyperopt) (0.4.4)
# Using legacy 'setup.py install' for future, since package 'wheel' is not installed.
# Installing collected packages: py4j, tqdm, networkx, future, cloudpickle, hyperopt
#   Running setup.py install for future: started
#   Running setup.py install for future: finished with status 'done'
# Successfully installed cloudpickle-2.2.1 future-0.18.3 hyperopt-0.2.7 networkx-3.1 py4j-0.10.9.7 tqdm-4.65.0
# WARNING: You are using pip version 22.0.4; however, version 23.1.2 is available.
# You should consider upgrading via the 'C:\Program Files\Python39\python.exe -m pip install --upgrade pip' command.

# %%
import numpy as np
import pandas as pd
from functools import partial
from sklearn import ensemble
from sklearn import metrics
from sklearn import model_selection
from hyperopt import hp, fmin, tpe, Trials
from hyperopt.pyll.base import scope

# %%
def optimize_hypo(params, x, y):
   """
   The main optimization function. 
   This function takes all the arguments from the search space
   and training features and targets. It then initializes
   the models by setting the chosen parameters and runs 
   cross-validation and returns a negative accuracy score
   :param params: dict of params from hyperopt
   :param x: training data
   :param y: labels/targets
   :return: negative accuracy after 5 folds
   """
   # initialize model with current parameters
   model = ensemble.RandomForestClassifier(**params)
   # initialize stratified k-fold
   kf = model_selection.StratifiedKFold(n_splits=5)

   # initialize accuracy list
   accuracies_new = []

   # loop over all folds
   for idx in kf.split(X=x, y=y):
      train_idx, test_idx = idx[0], idx[1]
      xtrain = x[train_idx]
      ytrain = y[train_idx]
      xtest = x[test_idx]
      ytest = y[test_idx]

      # fit model for current fold
      model.fit(xtrain, ytrain)

      #create predictions
      preds = model.predict(xtest)

      # calculate and append accuracy
      fold_accuracy = metrics.accuracy_score(
      ytest,
      preds
      )
      accuracies_new.append(fold_accuracy)

   # return negative accuracy

   neg_accuracies = -1 * np.mean(accuracies_new)
   return neg_accuracies

# %%
# read the training data
data_df = pd.read_csv(r"C:\Users\lenovo\Desktop\Disha Github\Machine Learning Approaches\Machine-Learning\datasets\train.csv")

 # features are all columns without price_range
 # note that there is no id column in this dataset
 # here we have training features
X = data_df.drop("price_range", axis=1).values

 # and the targets
y = data_df.price_range.values

# %%
 # define a parameter space
 # now we use hyperopt 
param_space_hypo = {
 # quniform gives round(uniform(low, high) / q) * q
 # we want int values for depth and estimators

 "max_depth": scope.int(hp.quniform("max_depth", 1, 15, 1)),
 "n_estimators": scope.int(
 hp.quniform("n_estimators", 100, 1500, 1)
 ),
 # choice chooses from a list of values
 "criterion": hp.choice("criterion", ["gini", "entropy"]),
 # uniform chooses a value between two values
 "max_features": hp.uniform("max_features", 0, 1)
 }

# %%
# partial function
optimization_function_hypo = partial(
 optimize_hypo,
 x=X,
 y=y
 )

# %%
# initialize trials to keep logging information
trials = Trials()

# %%
# run hyperopt
hopt = fmin(
 fn=optimization_function_hypo,
 space=param_space_hypo,
 algo=tpe.suggest,
 max_evals=15,
 trials=trials
 )

print(hopt)
# Out:
# 100%|██████████| 15/15 [04:07<00:00, 16.48s/trial, best loss: -0.9085000000000001]
# {'criterion': 1, 'max_depth': 14.0, 'max_features': 0.9164623170029373, 'n_estimators': 514.0}

# %% [markdown]
# The ways of tuning hyperparameters described above are the most common, and these will work with almost all models: linear regression, logistic regression, tree-based methods, gradient boosting models such as xgboost,
# lightgbm, and even neural networks

# %% [markdown]
# When you create large models or introduce a lot of features, you also make it susceptible to overfitting the training data. To avoid
# overfitting, you need to introduce noise in training data features or penalize the cost function. This penalization is called regularization and helps with generalizing the model.
#
# - In linear models, the most common types of regularizations are L1 and L2. L1 is also known as Lasso regression and L2 as Ridge regression.
#
# - When it comes to neural networks, we use dropouts, the addition of augmentations, noise, etc. to regularize our models. Using hyper-parameter optimization, you can also find the correct penalty to use.

# %% [markdown]
# | Model | Optimize | Range of Values |
# |---|---|---|
# | Linear Regression | - fit_intercept <br><br> - normalize | - True/False <br><br>- True/False |
# | Ridge | - alpha <br><br> - fit_intercept <br><br> - normalize |-  0.01, 0.1, 1.0, 10, 100  <br><br>- True/False <br><br>- True/False |
# | k-neighbors | - n_neighbors <br><br> - p | - 2,4,8,16.... <br><br>- 2,3... |
# | svm | - C<br><br>- gamma<br><br>- class_weight |- 0.001,0.01..10..100..1000  <br><br>- ‘auto’, RandomSearch* <br><br>- ‘balanced’ , None |
# | Logistic Regression | - Penalty <br><br> - C | - 11 or l2 <br><br>-  0.001, 0.01…..10...100 |
# | Lasso | - alpha <br><br> - Normalize | -  0.1, 1.0, 10 <br><br>- True/False |
# | Random Forest | - n_estimators<br><br>- max_depth<br><br>- min_samples_split<br><br>- min_samples_leaf<br><br>- max features |- 120, 300, 500, 800, 1200<br><br>- 5, 8, 15, 25, 30, None<br><br>- 1, 2, 5, 10, 15, 100<br><br>- 1, 2, 5, 10<br><br>- log2, sqrt, None |
# | XGBoost | - eta<br><br>- gamma<br><br>- max_depth<br><br>- min_child_weight<br><br>- subsample<br><br>- colsample_bytree<br><br>- lambda<br><br>- alpha |- 0.01,0.015, 0.025, 0.05, 0.1<br><br>- 0.05-0.1,0.3,0.5,0.7,0.9,1.0<br><br>- 3, 5, 7, 9, 12, 15, 17, 25<br><br>- 1, 3, 5, 7<br><br>- 0.6, 0.7, 0.8, 0.9, 1.0<br><br>- 0.6, 0.7, 0.8, 0.9, 1.0<br><br>- 0.01-0.1, 1.0 , RandomSearch*<br><br>- 0, 0.1, 0.5, 1.0 RandomSearch*|
